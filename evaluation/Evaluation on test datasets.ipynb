# %%
import re

test_set_doc = 'difficult_validate.txt'
test_set_doc_checked = test_set_doc + '.checked'

# %% [markdown]
# ## Step 1: Load test set

# %%
test_items = []

with open(test_set_doc, encoding='utf-8') as infile:
    for line in infile:
        if not '\t' in line:
            continue
        test_items.append(line.strip().split('\t')[1].strip())

print(f'Loaded {len(test_items)} lines')
# Out:
# Loaded 310 lines

# %% [markdown]
# Test set annotation:
# - Preverb marked by a suffixed backslash followed by an ID number, e.g. `meg\1`
# - Word from which the preverb was separated marked by a pipe followed by the same ID number, e.g. `főzve|1`
# - Within the same line, different verb-prefix pairs must (obviously) receive different ID numbers.
# - Only single-digit ID numbers allowed.
# - A preverb that is not separated from any word in the sentence (ellipsis etc.) is marked with a zero ID:
#     * `"Hazakísérhetlek?" "Meg\0 hát."`
# - Any number of preverbs can have the 0 ID within the same line.
# - In the **difficult** dataset, a verb directly followed by preverb is only annotated if the preverb is not separated from the preceding verb:
#     * `főzte meg`
#     * but: `főzte|1 volna meg\1`
# - In the **general (easy)** dataset, the first pattern is annotated as well:
#     * `főzte|1 meg\1`
# - Normally there is a 1:1 correspondence between preverbs and verbs. However, there are exceptions, and these are annotated accordingly, e.g. `Se ki\1, se be\1 nem lehetett menni|1 Budakesziről`; `át-\1 meg átjárták|1`

# %% [markdown]
# ## Step 2: Check test set for errors and reformat for emtsv tok

# %%
with open(test_set_doc_checked, 'w', encoding='utf-8') as outfile:
    for t in test_items:
        prev_indices = re.findall(r'\\([1-5])', t)
        if prev_indices is None:
            print("No prevs:", t) # unannotated line
            continue
        verb_indices = re.findall(r'\|([1-5])', t)
        if (sorted(list(set(prev_indices))) != sorted(prev_indices) or # any duplicate indices
            sorted(list(set(verb_indices))) != sorted(verb_indices) or
            sorted(prev_indices) != sorted(verb_indices) # any unmatched indices
           ):
            print('Possible error:', t)
            print(prev_indices)
            print(verb_indices)
        t = re.sub(r'(\\|\|)(\d)(\S)', r'\1\2 \3', t)
        outfile.write(t.replace('\\', '_p').replace('|', '_v') + '\n')
# Out:
# Possible error: S így búslakodván érzetem csapkodásaiban, kedves anyám jutott eszembe, s el\1 is gondoltam|1, hogy bezzeg az ő kies kertjében más gyümölcs termik; s el\1 azt is, hogy az a gyümölcs most jobb volna nekem, mert anyám nem azt akarná, hogy én álljak helyt a bajban, hanem azt inkább, hogy az öröm állja meg mellettem a helyét.
# ['1', '1']
# ['1']

# %% [markdown]
# If there are errors, correct in input file, then back to step 1.

# %% [markdown]
# ## Step 3: Tokenize in emtsv, insert testid column, run morph,pos

# %%
# !cat {test_set_doc_checked} | docker run -i mtaril/emtsv tok > tok_output.txt

print("tok_output done")

with open('tok_output.txt', encoding='utf-8') as infile:
    with open('morph_input.txt', 'w', encoding='utf-8') as outfile:
        outfile.write(next(infile).strip() + '\ttestid\n')
        for line in infile:
            if line.strip() == '':
                outfile.write(line)
                continue
            testid = '.' # avoid removal of empty column by xtsv
            m = re.findall('_([pv]\d)', line)
            if m:
                testid = m[0]
                line = re.sub('_[pv]\d', '', line)
            outfile.write(line.strip() + '\t' + testid + '\n')

print("morph_input done")

# !cat morph_input.txt | docker run -i mtaril/emtsv morph,pos > pos_output.txt

print("pos_output done")
# Out:
# tok_output done
# morph_input done
# pos_output done

# %%
import sys
sys.path.append('../preverb')
from word import Word

# %% [markdown]
# ## Step 4: Check if preverbs are annotated as preverbs and verb-like tokens as verbs

# %%
from word import Word

with open('pos_output.txt', encoding='utf-8') as infile:
    header = next(infile)
    Word.features = header.strip().split('\t')
    for n, line in enumerate(infile):
        if line.strip() == '':
            continue
        token = Word(line.strip().split('\t'))
        if token.testid[0] == 'p' and not token.xpostag.startswith('[/Prev]'):
            print(f"Bad prev on line {n + 2}:", token, '\n')
        if token.testid[0] == 'v' and not token.xpostag.startswith('[/V]'):
            print(f"Bad verb (?) on line {n + 2}:", token, '\n')
# Out:
# Bad verb (?) on line 760: fogadható	" "	v1	[{"lemma": "fogadható", "tag": "[/Adj][Nom]", "morphana": "fogad[/V]=fogad+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "fogad[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "f:f o:o g:g a:a d:d :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	fogadható	[/Adj][Nom]
#
# Bad verb (?) on line 1146: avatkozás	" "	v1	[{"lemma": "avatkozás", "tag": "[/N][Nom]", "morphana": "avatkozik[/V]=avatkoz+ás[_Ger/N]=ás+[Nom]=", "readable": "avatkozik[/V]=avatkoz + ás[_Ger/N] + [Nom]", "twolevel": "a:a v:v a:a t:t k:k o:o z:z :i :k :[/V] á:á s:s :[_Ger/N] :[Nom]"}]	avatkozás	[/N][Nom]
#
# Bad verb (?) on line 1153: képzelhető	" "	v1	[{"lemma": "képzelhető", "tag": "[/Adj][Nom]", "morphana": "képzel[/V]=képzel+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "képzel[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "k:k é:é p:p z:z e:e l:l :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "képzelhető", "tag": "[/Adj][Nom]", "morphana": "képzelhető[/Adj]=képzelhető+[Nom]=", "readable": "képzelhető[/Adj] + [Nom]", "twolevel": "k:k é:é p:p z:z e:e l:l h:h e:e t:t ő:ő :[/Adj] :[Nom]"}]	képzelhető	[/Adj][Nom]
#
# Bad verb (?) on line 1280: felelő	" "	v1	[{"lemma": "felelő", "tag": "[/Adj][Nom]", "morphana": "felel[/V]=felel+ő[_ImpfPtcp/Adj]=ő+[Nom]=", "readable": "felel[/V] + ő[_ImpfPtcp/Adj] + [Nom]", "twolevel": "f:f e:e l:l e:e l:l :[/V] ő:ő :[_ImpfPtcp/Adj] :[Nom]"}]	felelő	[/Adj][Nom]
#
# Bad verb (?) on line 1298: ítélhető	" "	v2	[{"lemma": "ítélhető", "tag": "[/Adj][Nom]", "morphana": "ítél[/V]=ítél+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "ítél[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "í:í t:t é:é l:l :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}]	ítélhető	[/Adj][Nom]
#
# Bad verb (?) on line 1397: ébredőnek	" "	v1	[{"lemma": "ébredő", "tag": "[/Adj][Dat]", "morphana": "ébred[/V]=ébred+ő[_ImpfPtcp/Adj]=ő+nek[Dat]=nek", "readable": "ébred[/V] + ő[_ImpfPtcp/Adj] + nek[Dat]", "twolevel": "é:é b:b r:r e:e d:d :[/V] ő:ő :[_ImpfPtcp/Adj] n:n e:e k:k :[Dat]"}, {"lemma": "ébredő", "tag": "[/N][Dat]", "morphana": "ébredő[/N]=ébredő+nek[Dat]=nek", "readable": "ébredő[/N] + nek[Dat]", "twolevel": "é:é b:b r:r e:e d:d ő:ő :[/N] n:n e:e k:k :[Dat]"}]	ébredő	[/Adj][Dat]
#
# Bad verb (?) on line 1451: foghatók	" "	v1	[{"lemma": "fogható", "tag": "[/Adj][Pl][Nom]", "morphana": "fog[/N]=fog+hat[/V]=hat+ó[_ImpfPtcp/Adj]=ó+k[Pl]=k+[Nom]=", "readable": "fog[/N] + hat[/V] + ó[_ImpfPtcp/Adj] + k[Pl] + [Nom]", "twolevel": "f:f o:o g:g :[/N] h:h a:a t:t :[/V] ó:ó :[_ImpfPtcp/Adj] k:k :[Pl] :[Nom]"}, {"lemma": "fogható", "tag": "[/Adj][Pl][Nom]", "morphana": "fog[/V]=fog+ható[_ModPtcp/Adj]=ható+k[Pl]=k+[Nom]=", "readable": "fog[/V] + ható[_ModPtcp/Adj] + k[Pl] + [Nom]", "twolevel": "f:f o:o g:g :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] k:k :[Pl] :[Nom]"}, {"lemma": "fogható", "tag": "[/Adj][Pl][Nom]", "morphana": "fogható[/Adj]=fogható+k[Pl]=k+[Nom]=", "readable": "fogható[/Adj] + k[Pl] + [Nom]", "twolevel": "f:f o:o g:g h:h a:a t:t ó:ó :[/Adj] k:k :[Pl] :[Nom]"}]	fogható	[/Adj][Pl][Nom]
#
# Bad verb (?) on line 1785: mondható	" "	v1	[{"lemma": "mondható", "tag": "[/Adj][Nom]", "morphana": "mond[/V]=mond+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "mond[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "m:m o:o n:n d:d :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	mondható	[/Adj][Nom]
#
# Bad prev on line 1833: utánam	" "	p1	[{"lemma": "után", "tag": "[/Post][1Sg]", "morphana": "én[/N|Pro]=+után[/Post]=után+am[1Sg]=am", "readable": "én[/N|Pro]= + után[/Post] + am[1Sg]", "twolevel": ":é :n :[/N|Pro] u:u t:t á:á n:n :[/Post] a:a m:m :[ :1 :S :g :]"}]	után	[/Post][1Sg]
#
# Bad verb (?) on line 2123: Indulás	" "	v1	[{"lemma": "indulás", "tag": "[/N][Nom]", "morphana": "indul[/V]=indul+ás[_Ger/N]=ás+[Nom]=", "readable": "indul[/V] + ás[_Ger/N] + [Nom]", "twolevel": "i:i n:n d:d u:u l:l :[/V] á:á s:s :[_Ger/N] :[Nom]"}, {"lemma": "indulás", "tag": "[/N][Nom]", "morphana": "indulás[/N]=indulás+[Nom]=", "readable": "indulás[/N] + [Nom]", "twolevel": "i:i n:n d:d u:u l:l á:á s:s :[/N] :[Nom]"}]	indulás	[/N][Nom]
#
# Bad verb (?) on line 2470: bányászható	" "	v1	[{"lemma": "bányászható", "tag": "[/Adj][Nom]", "morphana": "bány<a>ász[/N]=bányász+hat[/V]=hat+ó[_ImpfPtcp/Adj]=ó+[Nom]=", "readable": "bány<a>ász[/N]=bányász + hat[/V] + ó[_ImpfPtcp/Adj] + [Nom]", "twolevel": "b:b á:á n:n y:y á:< s:a z:> :á :s :z :[/N] h:h a:a t:t :[/V] ó:ó :[_ImpfPtcp/Adj] :[Nom]"}, {"lemma": "bányászható", "tag": "[/Adj][Nom]", "morphana": "bányászik[/V]=bányász+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "bányászik[/V]=bányász + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "b:b á:á n:n y:y á:á s:s z:z :i :k :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	bányászható	[/Adj][Nom]
#
# Bad verb (?) on line 3268: érhető	" "	v1	[{"lemma": "érhető", "tag": "[/Adj][Nom]", "morphana": "ér[/V]=ér+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "ér[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "é:é r:r :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "érhető", "tag": "[/Adj][Nom]", "morphana": "érik[/V]=ér+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "érik[/V]=ér + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "é:é r:r :i :k :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}]	érhető	[/Adj][Nom]
#
# Bad verb (?) on line 4381: adhatók	" "	v1	[{"lemma": "adható", "tag": "[/Adj][Pl][Nom]", "morphana": "ad[/V]=ad+ható[_ModPtcp/Adj]=ható+k[Pl]=k+[Nom]=", "readable": "ad[/V] + ható[_ModPtcp/Adj] + k[Pl] + [Nom]", "twolevel": "a:a d:d :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] k:k :[Pl] :[Nom]"}]	adható	[/Adj][Pl][Nom]
#
# Bad verb (?) on line 4509: emelhető	" "	v1	[{"lemma": "emelhető", "tag": "[/Adj][Nom]", "morphana": "emel[/V]=emel+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "emel[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "e:e m:m e:e l:l :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}]	emelhető	[/Adj][Nom]
#
# Bad verb (?) on line 4783: küldött	" "	v1	[{"lemma": "küld", "tag": "[/V][Pst.NDef.3Sg]", "morphana": "küld[/V]=küld+ött[Pst.NDef.3Sg]=ött", "readable": "küld[/V] + ött[Pst.NDef.3Sg]", "twolevel": "k:k ü:ü l:l d:d :[/V] ö:ö t:t t:t :[Pst.NDef.3Sg]"}, {"lemma": "küldött", "tag": "[/Adj][Nom]", "morphana": "küld[/V]=küld+ött[_PerfPtcp/Adj]=ött+[Nom]=", "readable": "küld[/V] + ött[_PerfPtcp/Adj] + [Nom]", "twolevel": "k:k ü:ü l:l d:d :[/V] ö:ö t:t t:t :[_PerfPtcp/Adj] :[Nom]"}, {"lemma": "küldött", "tag": "[/Adj][Nom]", "morphana": "küldött[/Adj]=küldött+[Nom]=", "readable": "küldött[/Adj] + [Nom]", "twolevel": "k:k ü:ü l:l d:d ö:ö t:t t:t :[/Adj] :[Nom]"}, {"lemma": "küldött", "tag": "[/N][Nom]", "morphana": "küldött[/N]=küldött+[Nom]=", "readable": "küldött[/N] + [Nom]", "twolevel": "k:k ü:ü l:l d:d ö:ö t:t t:t :[/N] :[Nom]"}]	küldött	[/Adj][Nom]
#
# Bad verb (?) on line 5041: zárva	" "	v1	[{"lemma": "zár", "tag": "[/V][_AdvPtcp/Adv]", "morphana": "zár[/V]=zár+va[_AdvPtcp/Adv]=va", "readable": "zár[/V] + va[_AdvPtcp/Adv]", "twolevel": "z:z á:á r:r :[/V] v:v a:a :[_AdvPtcp/Adv]"}, {"lemma": "zárva", "tag": "[/Adv]", "morphana": "zárva[/Adv]=zárva", "readable": "zárva[/Adv]", "twolevel": "z:z á:á r:r v:v a:a :[/Adv]"}]	zárva	[/Adv]
#
# Bad verb (?) on line 5120: használható	" "	v1	[{"lemma": "használható", "tag": "[/Adj][Nom]", "morphana": "használ[/V]=használ+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "használ[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "h:h a:a s:s z:z n:n á:á l:l :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "használható", "tag": "[/Adj][Nom]", "morphana": "használható[/Adj]=használható+[Nom]=", "readable": "használható[/Adj] + [Nom]", "twolevel": "h:h a:a s:s z:z n:n á:á l:l h:h a:a t:t ó:ó :[/Adj] :[Nom]"}]	használható	[/Adj][Nom]
#
# Bad verb (?) on line 5174: valósítható	" "	v1	[{"lemma": "valósítható", "tag": "[/Adj][Nom]", "morphana": "való[/Adj]=való+sít[_AdjVbz_Tr/V]=sít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "való[/Adj] + sít[_AdjVbz_Tr/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "v:v a:a l:l ó:ó :[/Adj] s:s í:í t:t :[_AdjVbz_Tr/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "valósítható", "tag": "[/Adj][Nom]", "morphana": "való[/N]=való+s[_Adjz:s/Adj]=s+ít[_AdjVbz_Tr/V]=ít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "való[/N] + s[_Adjz:s/Adj] + ít[_AdjVbz_Tr/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "v:v a:a l:l ó:ó :[/N] s:s :[_Adjz:s/Adj] í:í t:t :[_AdjVbz_Tr/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "valósítható", "tag": "[/Adj][Nom]", "morphana": "valós[/Adj]=valós+ít[_AdjVbz_Tr/V]=ít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "valós[/Adj] + ít[_AdjVbz_Tr/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "v:v a:a l:l ó:ó s:s :[/Adj] í:í t:t :[_AdjVbz_Tr/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "valósítható", "tag": "[/Adj][Nom]", "morphana": "valósít[/V]=valósít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "valósít[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "v:v a:a l:l ó:ó s:s í:í t:t :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	valósítható	[/Adj][Nom]
#
# Bad verb (?) on line 5228: válthatók	" "	v1	[{"lemma": "váltható", "tag": "[/Adj][Pl][Nom]", "morphana": "vált[/V]=vált+ható[_ModPtcp/Adj]=ható+k[Pl]=k+[Nom]=", "readable": "vált[/V] + ható[_ModPtcp/Adj] + k[Pl] + [Nom]", "twolevel": "v:v á:á l:l t:t :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] k:k :[Pl] :[Nom]"}]	váltható	[/Adj][Pl][Nom]
#
# Bad verb (?) on line 5292: fordult	" "	v1	[{"lemma": "fordul", "tag": "[/V][Pst.NDef.3Sg]", "morphana": "fordul[/V]=fordul+t[Pst.NDef.3Sg]=t", "readable": "fordul[/V] + t[Pst.NDef.3Sg]", "twolevel": "f:f o:o r:r d:d u:u l:l :[/V] t:t :[Pst.NDef.3Sg]"}, {"lemma": "fordult", "tag": "[/Adj][Nom]", "morphana": "fordul[/V]=fordul+t[_PerfPtcp/Adj]=t+[Nom]=", "readable": "fordul[/V] + t[_PerfPtcp/Adj] + [Nom]", "twolevel": "f:f o:o r:r d:d u:u l:l :[/V] t:t :[_PerfPtcp/Adj] :[Nom]"}]	fordult	[/Adj][Nom]
#
# Bad verb (?) on line 5635: térítendő	" "	v2	[{"lemma": "térítendő", "tag": "[/Adj][Nom]", "morphana": "térít[/V]=térít+endő[_FutPtcp/Adj]=endő+[Nom]=", "readable": "térít[/V] + endő[_FutPtcp/Adj] + [Nom]", "twolevel": "t:t é:é r:r í:í t:t :[/V] e:e n:n d:d ő:ő :[_FutPtcp/Adj] :[Nom]"}]	térítendő	[/Adj][Nom]
#
# Bad verb (?) on line 5663: térítendő	" "	v3	[{"lemma": "térítendő", "tag": "[/Adj][Nom]", "morphana": "térít[/V]=térít+endő[_FutPtcp/Adj]=endő+[Nom]=", "readable": "térít[/V] + endő[_FutPtcp/Adj] + [Nom]", "twolevel": "t:t é:é r:r í:í t:t :[/V] e:e n:n d:d ő:ő :[_FutPtcp/Adj] :[Nom]"}]	térítendő	[/Adj][Nom]
#
# Bad verb (?) on line 5769: mondható	" "	v1	[{"lemma": "mondható", "tag": "[/Adj][Nom]", "morphana": "mond[/V]=mond+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "mond[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "m:m o:o n:n d:d :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	mondható	[/Adj][Nom]
#
# Bad verb (?) on line 6039: állapítható	" "	v1	[{"lemma": "állapítható", "tag": "[/Adj][Nom]", "morphana": "állapít[/V]=állapít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "állapít[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "á:á l:l l:l a:a p:p í:í t:t :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	állapítható	[/Adj][Nom]
#
# Bad verb (?) on line 6148: töltött	" "	v2	[{"lemma": "tölt", "tag": "[/V][Pst.NDef.3Sg]", "morphana": "tölt[/V]=tölt+ött[Pst.NDef.3Sg]=ött", "readable": "tölt[/V] + ött[Pst.NDef.3Sg]", "twolevel": "t:t ö:ö l:l t:t :[/V] ö:ö t:t t:t :[Pst.NDef.3Sg]"}, {"lemma": "töltött", "tag": "[/Adj][Nom]", "morphana": "tölt[/V]=tölt+ött[_PerfPtcp/Adj]=ött+[Nom]=", "readable": "tölt[/V] + ött[_PerfPtcp/Adj] + [Nom]", "twolevel": "t:t ö:ö l:l t:t :[/V] ö:ö t:t t:t :[_PerfPtcp/Adj] :[Nom]"}, {"lemma": "töltött", "tag": "[/Adj|Attr][Nom]", "morphana": "töltött[/Adj|Attr]=töltött+[Nom]=", "readable": "töltött[/Adj|Attr] + [Nom]", "twolevel": "t:t ö:ö l:l t:t ö:ö t:t t:t :[/Adj|Attr] :[Nom]"}]	töltött	[/Adj][Nom]
# Bad verb (?) on line 6373: érhető	" "	v1	[{"lemma": "érhető", "tag": "[/Adj][Nom]", "morphana": "ér[/V]=ér+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "ér[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "é:é r:r :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "érhető", "tag": "[/Adj][Nom]", "morphana": "érik[/V]=ér+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "érik[/V]=ér + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "é:é r:r :i :k :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}]	érhető	[/Adj][Nom]
#
# Bad verb (?) on line 6687: osztható	" "	v2	[{"lemma": "osztható", "tag": "[/Adj][Nom]", "morphana": "oszt[/V]=oszt+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "oszt[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "o:o s:s z:z t:t :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}, {"lemma": "osztható", "tag": "[/Adj][Nom]", "morphana": "osztható[/Adj]=osztható+[Nom]=", "readable": "osztható[/Adj] + [Nom]", "twolevel": "o:o s:s z:z t:t h:h a:a t:t ó:ó :[/Adj] :[Nom]"}]	osztható	[/Adj][Nom]
#
# Bad verb (?) on line 6841: osztott	" "	v1	[{"lemma": "oszt", "tag": "[/V][Pst.NDef.3Sg]", "morphana": "oszt[/V]=oszt+ott[Pst.NDef.3Sg]=ott", "readable": "oszt[/V] + ott[Pst.NDef.3Sg]", "twolevel": "o:o s:s z:z t:t :[/V] o:o t:t t:t :[Pst.NDef.3Sg]"}, {"lemma": "osztott", "tag": "[/Adj][Nom]", "morphana": "oszt[/V]=oszt+ott[_PerfPtcp/Adj]=ott+[Nom]=", "readable": "oszt[/V] + ott[_PerfPtcp/Adj] + [Nom]", "twolevel": "o:o s:s z:z t:t :[/V] o:o t:t t:t :[_PerfPtcp/Adj] :[Nom]"}, {"lemma": "osztott", "tag": "[/Adj][Nom]", "morphana": "osztott[/Adj]=osztott+[Nom]=", "readable": "osztott[/Adj] + [Nom]", "twolevel": "o:o s:s z:z t:t o:o t:t t:t :[/Adj] :[Nom]"}]	osztott	[/Adj][Nom]
#
# Bad verb (?) on line 6849: osztott	" "	v2	[{"lemma": "oszt", "tag": "[/V][Pst.NDef.3Sg]", "morphana": "oszt[/V]=oszt+ott[Pst.NDef.3Sg]=ott", "readable": "oszt[/V] + ott[Pst.NDef.3Sg]", "twolevel": "o:o s:s z:z t:t :[/V] o:o t:t t:t :[Pst.NDef.3Sg]"}, {"lemma": "osztott", "tag": "[/Adj][Nom]", "morphana": "oszt[/V]=oszt+ott[_PerfPtcp/Adj]=ott+[Nom]=", "readable": "oszt[/V] + ott[_PerfPtcp/Adj] + [Nom]", "twolevel": "o:o s:s z:z t:t :[/V] o:o t:t t:t :[_PerfPtcp/Adj] :[Nom]"}, {"lemma": "osztott", "tag": "[/Adj][Nom]", "morphana": "osztott[/Adj]=osztott+[Nom]=", "readable": "osztott[/Adj] + [Nom]", "twolevel": "o:o s:s z:z t:t o:o t:t t:t :[/Adj] :[Nom]"}]	osztott	[/Adj][Nom]
#
# Bad verb (?) on line 6868: osztott	" "	v3	[{"lemma": "oszt", "tag": "[/V][Pst.NDef.3Sg]", "morphana": "oszt[/V]=oszt+ott[Pst.NDef.3Sg]=ott", "readable": "oszt[/V] + ott[Pst.NDef.3Sg]", "twolevel": "o:o s:s z:z t:t :[/V] o:o t:t t:t :[Pst.NDef.3Sg]"}, {"lemma": "osztott", "tag": "[/Adj][Nom]", "morphana": "oszt[/V]=oszt+ott[_PerfPtcp/Adj]=ott+[Nom]=", "readable": "oszt[/V] + ott[_PerfPtcp/Adj] + [Nom]", "twolevel": "o:o s:s z:z t:t :[/V] o:o t:t t:t :[_PerfPtcp/Adj] :[Nom]"}, {"lemma": "osztott", "tag": "[/Adj][Nom]", "morphana": "osztott[/Adj]=osztott+[Nom]=", "readable": "osztott[/Adj] + [Nom]", "twolevel": "o:o s:s z:z t:t o:o t:t t:t :[/Adj] :[Nom]"}]	osztott	[/Adj][Nom]
#
# Bad verb (?) on line 6892: állapítható	" "	v1	[{"lemma": "állapítható", "tag": "[/Adj][Nom]", "morphana": "állapít[/V]=állapít+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "állapít[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "á:á l:l l:l a:a p:p í:í t:t :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	állapítható	[/Adj][Nom]
#
# Bad verb (?) on line 6910: szabható	" "	v1	[{"lemma": "szabható", "tag": "[/Adj][Nom]", "morphana": "szab[/V]=szab+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "szab[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "s:s z:z a:a b:b :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	szabható	[/Adj][Nom]
#
# Bad verb (?) on line 6919: kapcsolható	" "	v2	[{"lemma": "kapcsolható", "tag": "[/Adj][Nom]", "morphana": "kapcsol[/V]=kapcsol+ható[_ModPtcp/Adj]=ható+[Nom]=", "readable": "kapcsol[/V] + ható[_ModPtcp/Adj] + [Nom]", "twolevel": "k:k a:a p:p c:c s:s o:o l:l :[/V] h:h a:a t:t ó:ó :[_ModPtcp/Adj] :[Nom]"}]	kapcsolható	[/Adj][Nom]
#
# Bad verb (?) on line 7147: élhető	" "	v1	[{"lemma": "élhető", "tag": "[/Adj][Nom]", "morphana": "él[/V]=él+hető[_ModPtcp/Adj]=hető+[Nom]=", "readable": "él[/V] + hető[_ModPtcp/Adj] + [Nom]", "twolevel": "é:é l:l :[/V] h:h e:e t:t ő:ő :[_ModPtcp/Adj] :[Nom]"}]	élhető	[/Adj][Nom]
#
# Bad verb (?) on line 8382: haladó	" "	v1	[{"lemma": "haladó", "tag": "[/Adj][Nom]", "morphana": "hal[/N]=hal+ad[/V]=ad+ó[_ImpfPtcp/Adj]=ó+[Nom]=", "readable": "hal[/N] + ad[/V] + ó[_ImpfPtcp/Adj] + [Nom]", "twolevel": "h:h a:a l:l :[/N] a:a d:d :[/V] ó:ó :[_ImpfPtcp/Adj] :[Nom]"}, {"lemma": "haladó", "tag": "[/N][Nom]", "morphana": "hal[/N]=hal+adó[/N]=adó+[Nom]=", "readable": "hal[/N] + adó[/N] + [Nom]", "twolevel": "h:h a:a l:l :[/N] a:a d:d ó:ó :[/N] :[Nom]"}, {"lemma": "haladó", "tag": "[/Adj][Nom]", "morphana": "halad[/V]=halad+ó[_ImpfPtcp/Adj]=ó+[Nom]=", "readable": "halad[/V] + ó[_ImpfPtcp/Adj] + [Nom]", "twolevel": "h:h a:a l:l a:a d:d :[/V] ó:ó :[_ImpfPtcp/Adj] :[Nom]"}, {"lemma": "haladó", "tag": "[/Adj][Nom]", "morphana": "haladó[/Adj]=haladó+[Nom]=", "readable": "haladó[/Adj] + [Nom]", "twolevel": "h:h a:a l:l a:a d:d ó:ó :[/Adj] :[Nom]"}, {"lemma": "haladó", "tag": "[/N][Nom]", "morphana": "haladó[/N]=haladó+[Nom]=", "readable": "haladó[/N] + [Nom]", "twolevel": "h:h a:a l:l a:a d:d ó:ó :[/N] :[Nom]"}]	haladó	[/Adj][Nom]

# %% [markdown]
# If there is any output, the line numbers refer to `pos_output.txt`.
#
# Check whether tokens annotated as separated preverbs are also analysed by morph,pos as preverbs. If not (e.g. if the preverb _meg_ is tagged by emtsv as a `[/Conj]`), **remove this annotation** (or the whole item if no annotation left) from the test set because `preverb` will necessarily fail due to incorrect emtsv annotation, which is extraneous to its performance evaluation.
#
# Exception: person-inflected preverb-like postpositions such as in `utánam\1 dobják|1`, which are tagged by emtsv as `[/Post]`, and case-inflected personal pronouns such as in `hozzá\1 voltam szokva|1`, which are tagged as `[/N|Pro]`, **should not be removed from the test set** since `preverb` should be able to handle these.
#
# If a token is annotated as the verb stem counterpart of a separated preverb, but is not tagged by emtsv as a verb, check whether the preverb annotation is correct, but if so, **do not remove this annotation** from the test set. `preverb` is supposed to be able to handle the connection of such separated preverbs.
#
# After all real errors have been corrected, rerun everything from step 1.

# %%
# !cat pos_output.txt | python ../preverb > preverb_output.tsv

# %% [markdown]
# ## Step 5: Verify diffs

# %% [markdown]
# NB: ONLY DO THIS ON THE VALIDATION DATASET.

# %%
def print_error(error_str, n, token):
    print(error_str, f"on token {n + 2}: {token.form}")

with open('preverb_output.tsv', encoding='utf-8') as infile:
    header = next(infile)
    Word.features = header.strip().split('\t')
    curr_sent = ''
    testid_to_previd = {}
    annotated_previds = {}
    irrelevant_previds = {}
    bad_flag = False
    for n, token in enumerate(infile):
        if token.strip() == '':
            if bad_flag:
                print(curr_sent, "\n")
            curr_sent = ''
            bad_flag = False
            testid_to_previd = {}
            annotated_previds = {}
            irrelevant_previds = {}
            continue
        token = Word(token.strip('\n').split('\t'))
        token_suffix = token.testid
        if token_suffix == '.':
            token_suffix = ''
        else:
            token_suffix = '_' + token_suffix
        curr_sent += token.form + token_suffix + token.wsafter.replace('"','')
        
        if token.testid == 'p0':
            if token.prev == 'conn':
                print_error("Incorrectly connected preverb", n, token)
            continue
        
        if token.testid[0] == 'p' and not token.prev == 'conn':
            print_error("Preverb mismatch", n, token)
            bad_flag = True
            continue
        elif token.testid[0] == 'v' and not token.prev == 'sep':
            print_error("Verb mismatch", n, token)
            bad_flag = True
            continue
        elif token.testid == '.' and token.previd != '':
            if token.previd in annotated_previds:
                print_error("Unannotated token connected to annotated", n, token)
                print(f"Incorrectly connected to {annotated_previds[token.previd]}")
                bad_flag = True
            else:
                irrelevant_previds[token.previd] = token.form
            continue
        elif token.previd == '':
            continue

        if token.previd in irrelevant_previds:
            print_error("Annotated token connected to unannotated", n, token)
            print(f"Incorrectly connected to {irrelevant_previds[token.previd]}")
            bad_flag = True
        elif token.testid[1] not in testid_to_previd:
            testid_to_previd[token.testid[1]] = token.previd
            annotated_previds[token.previd] = token.form
        elif testid_to_previd[token.testid[1]] != token.previd:
            print_error("Annotated token index mismatch", n, token)
            bad_flag = True
# Out:
# Unannotated token connected to annotated on token 295: lehetne
# Incorrectly connected to el
# Verb mismatch on token 299: mondani
# Akkor Fehérlófia önkéntelenül magához ölelte És mintha nem is ő tenné megcsókolta Krisztina száját Sután ügyetlenül mert összekoccant a foguk Rögtön elengedte hátra_p1 is lépett_v1 tőle Zavarában el_p2 sem búcsúzott_v2 szaladt vissza_p3 se nézve_v3 Megcsókoltam ismételte ujjongva magában Megcsókoltam igen itt maradunk a hazában Együtt a hazában édes vagy édes édes\nEzt persze el_p4 lehetne nem-költői módon is mondani_v4 , de mennyivel nagyobb dolog, ha ez költői megfogalmazást kap.
#
# Verb mismatch on token 585: Fölidézte
# Preverb mismatch on token 603: föl
# Preverb mismatch on token 647: át-
# Verb mismatch on token 649: átjárták
# Fölidézte_v1 magában Veron jobbjának barátságos szorítását, hangjának zengését, derűs szemének biztató csillámát és jó mosolyát, föl_p1 a mély beszélgetéseket, amikor már azt hitte István, elmondott mindent, s Veron halkan kérdezni kezdett, aprók, szinte tőmondatosak voltak a kérdései, amelyekből azonban kiderült, hogy mégse mondott_v2 István el_p2 mindent, a kérdések s megjegyzések szavai át-_p3 meg átjárták_v3 az elmondottak homályos zugait, s aztán Veron magyarázni kezdett, megmagyarázta: mit látott István, és miért látta, amit látott, olyannak, amilyennek.\n
#
# Preverb mismatch on token 1653: meg
# Verb mismatch on token 1657: fagyva
# Hol elöl, hol hátul ültek egyre többen, s a hó nőtt akkorára, hogy ha meg_p1 nem lett volna fagyva_v1 , ki_p2 sem látszik_v2 belőle az ember.\n
#
# Preverb mismatch on token 1833: utánam
# Verb mismatch on token 1834: dobják
# Pedig a többiek már trappolnak is az emeletről, hogy újra utánam_p1 dobják_v1 , mert dühük már fáj: csak annyit éreznek, hogy mekkora feszültség van egy mozdulatlanul álló szörnyű nagy kőtömbben.\n
#
# Verb mismatch on token 2057: visszamutat
# Preverb mismatch on token 2065: vissza
# Vajon nem törülné_v1 -e el_p1 azt a magabiztos mozdulatát, mellyel a XX. századi Csák visszamutat_v2 ma a dunántúli város középkori történetére, vissza_p2 a ködszerű múltra.\n
#
# Verb mismatch on token 2123: Indulás
# Preverb mismatch on token 2124: haza
# Indulás_v1 haza_p1 !\n
#
# Incorrectly connected preverb on token 3283: Szét
# Verb mismatch on token 3543: bújt
# Preverb mismatch on token 3546: be
# "\nHogy menekűlt az a réműlt kukac, mikor szétbuggyantottad rejtekét! hogy bújt, vissza, az eltűnt éjbe! még beljebb, a mag alá! hogy bújt_v1 csupasz titka be_p1 a takaró húsba, az áldott édenbe, a biztosba!...
#
# Preverb mismatch on token 4012: el
# S így búslakodván érzetem csapkodásaiban, kedves anyám jutott eszembe, s el_p1 is gondoltam_v1 , hogy bezzeg az ő kies kertjében más gyümölcs termik; s el_p1 azt is, hogy az a gyümölcs most jobb volna nekem, mert anyám nem azt akarná, hogy én álljak helyt a bajban, hanem azt inkább, hogy az öröm állja meg mellettem a helyét.\n
#
# Verb mismatch on token 4164: kapja
# Preverb mismatch on token 4167: el
# De Jucika riadtan kapja_v1 a kezét el_p1 .\n
#
# Preverb mismatch on token 4916: el
# Verb mismatch on token 4920: hárítsak
# Egyet nagyon határozottan el_p1 kell, hogy hárítsak_v1 : akkor mi nem tartoztunk a kormányzó pártok közé.\n
#
# Verb mismatch on token 7207: feledd
# Unannotated token connected to annotated on token 7208: tisztázni
# Incorrectly connected to el
# Pl. hogy ki szegte meg szavát: el_p1 ne feledd_v1 tisztázni.\n
#
# Preverb mismatch on token 7731: fel
# Verb mismatch on token 7735: hozni
# Az esetek többségében a válaszban szereplő szám mindig meg_p1 tudtam számolni_v1 két ujjamon ;-) Viszont tapasztaltam azt is, hogy sokan a légitársaságnak rónak fel egy csomó olyan dolgot, amiről abszolúte nem tehetnek (pl. felszálláskor liftezett a gép, hülye pilóta ;-))\nSzerintem is jól döntöttek, de a kevésbé durva helyzetekre nézve nem hiszem hogy fel_p2 lehet ezt példaként hozni_v2 .\nterembura-ragi úgy sorolod ezeket a faszságokat, mintha legalábbis te intézted volna, hogy odaát ilyen jó élet legyen. ne felejcsd el lécci, hogy a készbe menekültél át, az USÁ-ban már minden megvolt előtted. tiszteljük egyébként a fogadott hazád iránti szeretedet, és megértjük az identitászavart is, de vissza_p3 lehet venni_v3 az arcból.\n

# %% [markdown]
# ## Step 6: Calculate evaluation metrics

# %%
# A debuggal sorok csak debugoláshoz / átláthatósághoz kellenek, és törölhetők, ha minden jó így.

preverb_count, true_pos, false_pos, true_neg, false_neg = 0, 0, 0, 0, 0

with open('preverb_output.tsv', encoding='utf-8') as infile:
    header = next(infile)
    Word.features = header.strip().split('\t')

    curr_sent = '' # debug

    p_testids = {}
    v_testids = {}
    irrelevant_previds = []

    for n, token in enumerate(infile):
        if token.strip() == '':
            for p_testid, p_previd in p_testids.items():
                if (p_previd in irrelevant_previds or  # \i is connected to a non-annotated verb
                    p_testid not in v_testids or       # \i is not connected to any annotated verbs
                    v_testids[p_testid] != p_previd):  # \i is not connected to |i, but some other |j
                    false_pos += 1
                    print("False pos", p_testid) # debug
                else: 
                    true_pos += 1
                    print("True pos", p_testid) # debug
            print(curr_sent)  # debug
            print("P:", p_testids) # debug
            print("V:", v_testids) # debug
            print("Irrel:", irrelevant_previds) # debug
            curr_sent = '' # debug
            p_testids = {}
            v_testids = {}
            irrelevant_previds = []
            print() # debug
            continue
        
        token = Word(token.strip('\n').split('\t'))
        token_suffix = token.testid # debug
        if token_suffix == '.': # debug
            token_suffix = '' # debug
        else: # debug
            token_suffix = '_' + token_suffix # debug
        curr_sent += token.form + token_suffix + token.wsafter.replace('"','') # debug
        
        if token.testid == '.':
            if token.previd != '':
                irrelevant_previds.append(token.previd)
            continue

        if token.testid == 'p0':
            preverb_count += 1
            if token.prev == 'conn':
                false_pos += 1   # preverb annotated as \0 connected to anything
                print("False pos") # debug
            else:
                true_neg += 1    # not connected, OK
                print("True neg") # debug
            continue
        
        if token.testid[0] == 'p':
            preverb_count += 1
            if token.prev != 'conn':
                false_neg += 1   # preverb annotated as \1 etc. should have been connected
                print("False neg", token.testid[1:]) # debug
            elif token.testid[1:] in p_testids and p_testids[token.testid[1:]] != token.previd:
                false_pos += 1   # previd does not match preverb with the same annotation
                print("False pos", token.testid[1:]) # debug
            else:
                p_testids[token.testid[1:]] = token.previd
            continue

        if token.testid[0] == 'v' and token.prev == 'sep':
            v_testids[token.testid[1:]] = token.previd        

print(preverb_count) # debug
print([true_pos, false_pos, true_neg, false_neg]) # debug
assert preverb_count == sum([true_pos, false_pos, true_neg, false_neg]) # debug
# Out:
# True pos 1
# True pos 2
# Be_p1 fog következni_v1 , mert be_p2 kell következzék_v2 az immár elkerülhetetlen totális civilizációs összeomlás.\n
# P: {'1': '1', '2': '2'}
# V: {'1': '1', '2': '2'}
# Irrel: []
#
# False pos 1
# S le_p1 is van írva_v1 .\n
# P: {'1': '3'}
# V: {}
# Irrel: ['3']
#
# True pos 1
# Jaj, annyi a gondom, hogy ki_p1 sem látszom_v1 belőle.\n
# P: {'1': '4'}
# V: {'1': '4'}
# Irrel: []
#
# True pos 1
# True pos 2
# Idő kérdése, de törvényszerűen alakul_v1 majd ki_p1 végül az a bizonyos új istenű és új módon értelmes világ, aminek el_p2 kell jönnie_v2 ...\n
# P: {'1': '5', '2': '6'}
# V: {'1': '5', '2': '6'}
# Irrel: []
#
# True pos 1
# Menne ő is szívesen (miként azt később meg_p1 is teszi_v1 ), de egyelőre még szerve zési feladatai vannak.\n
# P: {'1': '7'}
# V: {'1': '7'}
# Irrel: []
#
# True pos 1
# A nézőt valahogy meg_p1 kell tartani_v1 .\n
# P: {'1': '8'}
# V: {'1': '8'}
# Irrel: []
#
# True pos 1
# Melyhez mintha már hozzá_p1 is szoktunk_v1 volna, mely nélkül mintha már létezni sem tudnánk.\n
# P: {'1': '9'}
# V: {'1': '9'}
# Irrel: []
#
# True pos 1
# Mondták, hogy meg_p1 van igézve_v1 .\n
# P: {'1': '10'}
# V: {'1': '10'}
# Irrel: []
#
# True pos 1
# Előbb a kapuig mehettem el vele, majd később be_p1 is invitált_v1 .\n
# P: {'1': '12'}
# V: {'1': '12'}
# Irrel: ['11', '11']
#
# True pos 1
# - Vagyis valamennyi idegent ebben a faluban sürgősen meg_p1 kell semmisítenünk_v1 , még mielőtt észrevennének.\n
# P: {'1': '13'}
# V: {'1': '13'}
# Irrel: []
#
# True pos 1
# És megint csak hosszú ideig nem tartottam lehetségesnek, hogy bekövetkezzék, aminek pedig minden józan emberi számítás szerint be_p1 kellett következnie_v1 .\n
# P: {'1': '14'}
# V: {'1': '14'}
# Irrel: []
#
# True pos 1
# True pos 2
# Hatalmasat ugrott előre, egész testével erőlködve, megfeszítve magát, kockáztatva a móka kimenetelét, de be_p1 kellett látnia_v1 , hogy most csakugyan nincs menekvés, a csomók szakszerűen, precízen tartják, a játékot végig_p2 kell játszania_v2 .\n
# P: {'1': '15', '2': '16'}
# V: {'1': '15', '2': '16'}
# Irrel: []
#
# - Tessék csak papizgatni, kisasszonyka!
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Föl_p1 kell épülnie_v1 !\n
# P: {'1': '17'}
# V: {'1': '17'}
# Irrel: []
#
# True pos 1
# Nem gazdagít, megdolgoztat, de meg_p1 is adja_v1 az ünnepet.\n
# P: {'1': '18'}
# V: {'1': '18'}
# Irrel: []
#
# False neg 4
# True pos 1
# True pos 2
# True pos 3
# Akkor Fehérlófia önkéntelenül magához ölelte És mintha nem is ő tenné megcsókolta Krisztina száját Sután ügyetlenül mert összekoccant a foguk Rögtön elengedte hátra_p1 is lépett_v1 tőle Zavarában el_p2 sem búcsúzott_v2 szaladt vissza_p3 se nézve_v3 Megcsókoltam ismételte ujjongva magában Megcsókoltam igen itt maradunk a hazában Együtt a hazában édes vagy édes édes\nEzt persze el_p4 lehetne nem-költői módon is mondani_v4 , de mennyivel nagyobb dolog, ha ez költői megfogalmazást kap.
# P: {'1': '19', '2': '20', '3': '22'}
# V: {'1': '19', '2': '20', '3': '22'}
# Irrel: ['21']
#
# True pos 1
# "\nOttan aztán meg_p1 sem állva_v1 ?\n
# P: {'1': '23'}
# V: {'1': '23'}
# Irrel: []
#
# True pos 1
# Akkor most el_p1 fogja kaparni_v1 .\n
# P: {'1': '24'}
# V: {'1': '24'}
# Irrel: []
#
# True pos 1
# Továbbá föl_p1 fog kelni_v1 a nap, a fű sárgásan izzani kezd, s a távolban a város fölött, az öttízes és az öthúszas fölött a kéményekből mint távozó nagy halak úsznak elő a koszosabbnál koszosabb lila felhők.\n
# P: {'1': '25'}
# V: {'1': '25'}
# Irrel: ['26', '26']
#
# Nem ártott volna, ha a mészégető pár nappal hamarabb érkezik.
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# Be_p1 lehetett volna durrantani_v1 a vendégek fogadására szánt szobába.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Később tudtam_v1 csak meg_p1 , hogy a partraszállás óta Playa Giron nem kizárólag fürdőtelep, hanem halászati iskolaközpont is.\n
# P: {'1': '27'}
# V: {'1': '27'}
# Irrel: []
#
# True pos 1
# De a halált - az elnyújtható ravaszkodások ellenére - egyszer mégiscsak be_p1 kellett vallanunk_v1 .\n
# P: {'1': '28'}
# V: {'1': '28'}
# Irrel: []
#
# True pos 1
# True pos 2
# Gondoljuk_v1 csak el_p1 - Adyt idézve -, hogy a nagy vallási háborúságok idején Ázsia peremén akadt egy töredék ország, amely ki_p2 merte jelenteni_v2 , hogy az embereknek a hite az ő külön dolguk.\n
# P: {'1': '29', '2': '30'}
# V: {'1': '29', '2': '30'}
# Irrel: []
#
# True pos 1
# Az például meg_p1 sem fordult_v1 az agyunkban, hogy százmilliók lelki kiüresedése, elfáradása, undora anélkül is, hogy ennek a folyamatnak neve volna, nagyobb hatású forradalom lehet, mint amilyen a Nagy Októberi volt vagy 1956, illetve 1968.\n
# P: {'1': '31'}
# V: {'1': '31'}
# Irrel: []
#
# True pos 1
# És már húzta_v1 is fel_p1 a gipszlábát.\n
# P: {'1': '32'}
# V: {'1': '32'}
# Irrel: []
#
# True pos 1
# - Meg_p1 akart torolni_v1 valamit, de kizökkentettem a lelki egyensúlyából!\n
# P: {'1': '33'}
# V: {'1': '33'}
# Irrel: []
#
# - Hogy láttad, te locsifecsi?
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Be_p1 volt kötve_v1 a szemed!\n
# P: {'1': '34'}
# V: {'1': '34'}
# Irrel: []
#
# True pos 1
# Féltettem is, s ki_p1 akartam vetni_v1 magamból minden mást, szégyenkezve gondoltam apám sokarcú életére...\n
# P: {'1': '35'}
# V: {'1': '35'}
# Irrel: []
#
# True pos 1
# " Mutasd csak a szemüvegedet ", odanyúlt, el_p1 akartam kapni_v1 a fejem, azután mégsem mozdultam.\n
# P: {'1': '36'}
# V: {'1': '36'}
# Irrel: []
#
# False neg 1
# False neg 2
# False neg 3
# Fölidézte_v1 magában Veron jobbjának barátságos szorítását, hangjának zengését, derűs szemének biztató csillámát és jó mosolyát, föl_p1 a mély beszélgetéseket, amikor már azt hitte István, elmondott mindent, s Veron halkan kérdezni kezdett, aprók, szinte tőmondatosak voltak a kérdései, amelyekből azonban kiderült, hogy mégse mondott_v2 István el_p2 mindent, a kérdések s megjegyzések szavai át-_p3 meg átjárták_v3 az elmondottak homályos zugait, s aztán Veron magyarázni kezdett, megmagyarázta: mit látott István, és miért látta, amit látott, olyannak, amilyennek.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Ilyen szarságért be_p1 nem zárják_v1 .\n
# P: {'1': '37'}
# V: {'1': '37'}
# Irrel: []
#
# Lehetne például örülni annak, hogy milyen nagy tisztelői vagyunk a vallásnak, jelen esetben a mohamedán hitnek.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Meg_p1 lehetne kérdezni_v1 : egy ország megszállása és önvédelmi harca esetében csakugyan olyan lovagias képlet szerint folyik a játszma, hogy katona áll szemben katonával stb?\n
# P: {'1': '38'}
# V: {'1': '38'}
# Irrel: []
#
# False neg 1
# Sz.: Engem azért egy kicsit megrázott előbb, amikor azt mondta, hogy a pszichológiai bizonyítás annak ellenében, hogy Petőfi Szibériában nyugodnék, nem fogadható_v1 el_p1 .\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Ilyen elméleti útmutatások birtokában a magyar kommunisták teoretikusai természetesen erélyesen védték a Horthy-rendszerben elnyomott S.-ot, amikor még az is előfordult, hogy Illyés Gyulát egy vagy két napra le_p1 is tartóztatták_v1 izgatás címén.\n
# P: {'1': '39'}
# V: {'1': '39'}
# Irrel: []
#
# True pos 1
# Aki valamely köztársaságot alapít, el_p1 kell rendelnie_v1 , hogy szabad legyen bevádolni minden polgárt, minden félelem és gyanakvás nélkül.\n
# P: {'1': '40'}
# V: {'1': '40'}
# Irrel: []
#
# True pos 1
# Rákosiék Marxtól csak annyit vettek át, hogy a kispolgár reakciós - s ennek megfelelően mindent meg_p1 is tettek_v1 annak érdekében, hogy reakcióssá tegyék...\n
# P: {'1': '42'}
# V: {'1': '42'}
# Irrel: ['41', '41']
#
# True pos 1
# Hogy ez tegnap még egy öntelt, ifjú nő volt - s őt búcsúztatják_v1 ma el_p1 ?\n
# P: {'1': '43'}
# V: {'1': '43'}
# Irrel: []
#
# Érdekes írások voltak ezek, de valahogy hiányzott belőlük a meggyőződés lüktetése.
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# Meg_p1 kell végre hallani_v1 a kor szavát, Fokos kolléga!\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Felhívást kell készíteni a Minisztertanács nevében, ezt igen gondosan kell megírni, mint az események utáni első kormánydokumentumot..., mert az egész világ fel_p1 fog figyelni_v1 rá.\n
# P: {'1': '44'}
# V: {'1': '44'}
# Irrel: []
#
# True pos 1
# Pongrácz Gergely aznap érkezett a Corvin közbe, Angyal István még meg_p1 sem alakította_v1 csoportját.\n
# P: {'1': '45'}
# V: {'1': '45'}
# Irrel: []
#
# True neg
# True pos 1
# Taxi, haza, néhány ruhadarab, fogkefe, miegymás, be_p0 a bőröndbe mindent, kezembe az aktatáskát, taxi, rohanok a pályaudvarra, épp hogy elérem a vonatot, a vonat máris indul, mintha csak rám várt volna, nyúlok a zsebembe, rá_p1 akarok gyújtani_v1 , erős dohányos vagyok, elnök elvtárs, ez az egyetlen szenvedélyem, nem jó szenvedély, belátom, nem hasznos, de aki annyit dolgozik, mint mi, ezt szokta mondani Kalácska elvtárs, aki annyit dolgozik, az legalább egyetlen szenvedélyt megengedhet magának, hiszen a nép szolgálata nem aszkétákat követel, nem szerzeteseket, ezt már rég túlhaladtuk, szokta mondani Kalácska elvtárs.\n
# P: {'1': '46'}
# V: {'1': '46'}
# Irrel: []
#
# True pos 1
# - Át_p1 vannak itatva_v1 ...\n
# P: {'1': '47'}
# V: {'1': '47'}
# Irrel: []
#
# True pos 1
# Az emberek meg imbolyogtak az új szelekben, látni lehetett, hogy igyekeznek egymás segítségére, hogy végig_p1 ne vágódjanak_v1 a hatalmas sártócsákban.\n
# P: {'1': '48'}
# V: {'1': '48'}
# Irrel: []
#
# True pos 1
# De csak meg_p1 kell találnunk_v1 .\n
# P: {'1': '49'}
# V: {'1': '49'}
# Irrel: []
#
# False neg 1
# Vegye meg ezt, Ferdi bácsi - húzta ki Ildi a hóna alól, hogy odamutassa, Nadragulyevác Szávó üstökös életű költőnk örök érvényű tankölteményeinek öt egyforma kötetét, és elé nyújtotta, futószalagon (Aranyos Reske csak távolabbi szemlélője volt a jelenetnek, a be_p1 nem avatkozás_v1 elve alapján).\n
# P: {}
# V: {}
# Irrel: ['50', '50', '51', '51']
#
# False neg 1
# Nehezen képzelhető_v1 el_p1 ; de akkor is, mi volt a formája?\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Semmi olyat nem mondtam, amit az ön jelenlétében is meg_p1 ne ismételhetnék_v1 .\n
# P: {'1': '52'}
# V: {'1': '52'}
# Irrel: []
#
# True pos 1
# Nem akarnak egyéni érzelmeimben befolyásolni, de itt nem érzelmekről, hanem elvekről és tényekről van szó, és ha igazán az eszmélő nép, a " népünk ", valamint " a költészet, a tiszta szellem " mellé akarok állni, el_p1 kell fogadnom_v1 a nagy Petényi ujjmutatását, aki Réti Palit már negyvennégy nyarán, londoni emigrációjában, könyörtelenül az árulók közé taszította.\n
# P: {'1': '53'}
# V: {'1': '53'}
# Irrel: []
#
# Lépek s kiáltok.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# S zajongok, amig Egy röggel be_p1 nem tömik_v1 szájamat.\n
# P: {'1': '54'}
# V: {'1': '54'}
# Irrel: []
#
# False neg 1
# False neg 2
# Egyik-másik annyi tiszteletlenséget, izgatást, szemérmetlen (a való tényeknek egyáltalában meg_p1 nem felelő_v1 ) önleleplezést tartalmazott, hogy ezekért nem is vállalhattam a felelősséget egy olyan, eléggé el_p2 nem ítélhető_v2 jogrendszerben, amely ilyesmiért nem a korszellem és az örök szellem közös leányát, a Múzsát, hanem bűnös hanyagsággal a költőt vonja perbe.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# False pos 2
# Egy portugál bölcselő szerint, ha egy rétegtől munkaerőt, terményt, mindent olcsón meg_p1 lehet kapni_v1 , a vásárlók eszmevilága szükségszerűen úgy alakul, hogy el_p2 sem tudják képzelni_v2 : rendkívülinek, sőt afféle szerződésszegésnek érzik, ha valami mégsem olcsó, vagy kiváltképp nem kapható.\n
# P: {'1': '55', '2': '56'}
# V: {'1': '55'}
# Irrel: ['56']
#
# False neg 1
# Ti fogjátok tudtául adni, hogy Kolozsvár felett zivatar vonul, s nedveteknek hirtelen újjáéledése jelenti meg a mélyen alvónak és fel_p1 nem ébredőnek_v1 az újdonatúj tavaszt.\n
# P: {}
# V: {}
# Irrel: ['57', '57']
#
# True pos 1
# De ez is elég volt ahhoz, hogy az öregember el-elszoruló szívvel induljon lefelé a meredek kerten át, s meg_p1 se álljon_v1 az íróasztaláig.\n
# P: {'1': '58'}
# V: {'1': '58'}
# Irrel: []
#
# False neg 1
# Mintha valakiket megleptem volna itt, kik test szerint bár láthatatlanok, azóta súlyosabban itt lakoznak, mióta szemmel fel_p1 nem foghatók_v1 .\n
# P: {}
# V: {}
# Irrel: []
#
# Anya jópofa volt.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Meg_p1 kell hagyni_v1 .\n
# P: {'1': '59'}
# V: {'1': '59'}
# Irrel: []
#
# True pos 1
# Egyszerre... rétegesen... az egymásutániság csapdája, ha le_p1 akarnám írni_v1 ... ha valamelyik firkász venné a bátorságot és összerendezné... kikerekítgetné szépen... a vázlatot... a részleteket... öntelten kukorékolná, mint a kakas a szemétdombon, " nézzétek, emberek, ez az én művem, ezt mind én csináltam, egyes-egyedül, tőlem kelt fel az Isten napja...
# P: {'1': '60'}
# V: {'1': '60'}
# Irrel: ['61', '61']
#
# True pos 1
# "\nAmit fel_p1 lehet ragasztani_v1 .\n
# P: {'1': '62'}
# V: {'1': '62'}
# Irrel: []
#
# True pos 1
# És hogy meg_p1 tetszett tiltani_v1 neki, hogyha én otthon felejtem valamimet, ő kölcsönadja...\n
# P: {'1': '63'}
# V: {'1': '63'}
# Irrel: []
# Nem is volt botrány voltaképpen, mert a fürdőzők s úszómesterek egyaránt hazamentek, csak két három elkésett látogató csavarta ki vizes fürdőruháját, megállva a medence kőszegélyén.
# P: {}
# V: {}
# Irrel: ['64', '64']
#
# Mint később állították, nem hittek a saját szemüknek, megpillantva a szürkületben a meztelen alakokat.
# P: {}
# V: {}
# Irrel: []
#
# Azt képzelték, érzékcsalódás áldozatai lettek, avagy talán a délibáb Egerbe költözött a Hortobágyról.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Mikor pedig rá_p1 kellett jönniük_v1 , hogy nem káprázik a szemük, lóhalálában elhagyták a fürdőt.\n
# P: {'1': '65'}
# V: {'1': '65'}
# Irrel: []
#
# False pos 1
# True pos 2
# Hol elöl, hol hátul ültek egyre többen, s a hó nőtt akkorára, hogy ha meg_p1 nem lett volna fagyva_v1 , ki_p2 sem látszik_v2 belőle az ember.\n
# P: {'1': '66', '2': '67'}
# V: {'2': '67'}
# Irrel: ['66']
#
# True pos 1
# - Az Écel emberei be_p1 vannak építve_v1 a rendőrségre.\n
# P: {'1': '68'}
# V: {'1': '68'}
# Irrel: []
#
# True pos 1
# Most jön_v1 csak ki_p1 a szobából Mendezné, karján összehajtogatott takaró.\n
# P: {'1': '69'}
# V: {'1': '69'}
# Irrel: []
#
# True pos 1
# F. sokáig távol tartotta magát a sajtótól, mígnem néhány évvel ezelőtt egy népszerű napilap publicisztikai rovatvezetője - egykori kollégánk - felajánlotta neki a helyettesi státust, amit F. némi habozás után el_p1 is fogadott_v1 .\n
# P: {'1': '70'}
# V: {'1': '70'}
# Irrel: []
#
# True pos 1
# Azt is megbeszélték, hogy ő vásárol_v1 majd be_p1 szombaton.\n
# P: {'1': '71'}
# V: {'1': '71'}
# Irrel: []
#
# False neg 1
# Aztán el_p1 kellett még mondanom_v1 az öregasszonynak: - Együtt voltunk - magyarázkodnom: - Zeitzban -, s valahogyan szigorú, már-már számon kérő kérdésére: - És miért nem együtt jöttek haza? - mentegetőznöm szinte: - Elváltunk.\n
# P: {}
# V: {}
# Irrel: ['72', '72']
#
# False neg 1
# A ki_p1 nem mondható_v1 , de a társadalomban még élő igazság és jogérzet, a cselekvésre sarkalló akarat, az éber lelkiismeret jelenik meg velük a színen.\n
# P: {}
# V: {}
# Irrel: ['73', '73']
#
# Ide esett.
# P: {}
# V: {}
# Irrel: []
#
# Többet nem fogja megmoccantani senki.
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# Pedig a többiek már trappolnak is az emeletről, hogy újra utánam_p1 dobják_v1 , mert dühük már fáj: csak annyit éreznek, hogy mekkora feszültség van egy mozdulatlanul álló szörnyű nagy kőtömbben.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Mint egyike azoknak, akik mindig az egészben gondolkoztak, nem hittek abban, hogy valamilyen szempontok szerint le_p1 kellene írni_v1 holmi tételeket, amelyeket persze máshol se vennének úgysem könyvelésbe az ötbe-hatba-hétbe hasított egynyelvű kultúránkból.\n
# P: {'1': '74'}
# V: {'1': '74'}
# Irrel: []
#
# True pos 1
# Most a kora őszi csepergésben, a fénylő síneken ágyúval, horkoló katonákkal úgy kattogtak át itt is a vonatok, mint a legparányibb bakterház előtt; még nappal sem volt, hogy félrehúzott ajtókban láblógatva ücsörgő szürke alakok, bár kibetűzzék s egy pillanat múlva el_p1 is felejtsék_v1 , hogy van ilyen állomás...\n
# P: {'1': '76'}
# V: {'1': '76'}
# Irrel: ['75', '75']
#
# True pos 1
# Csóka talált a patakban egy vaskalapot, két helyen át_p1 volt lyuggatva_v1 , és tele volt iszappal.\n
# P: {'1': '77'}
# V: {'1': '77'}
# Irrel: []
#
# True pos 1
# -... ha meg kellett érteni: mi történik hirtelen bennem, fel_p1 kellett fogni_v1 , mit érzek, nagyon magamra voltam utalva.\n
# P: {'1': '79'}
# V: {'1': '79'}
# Irrel: ['78', '78']
#
# True pos 1
# Figyeljünk_v1 most oda_p1 egy, látszólag, formai vonásra.\n
# P: {'1': '80'}
# V: {'1': '80'}
# Irrel: []
#
# True pos 1
# - Na, ülj hamar a hátamra, estig vissza_p1 kell érnem_v1 , mert este szolgálatba megyek.\n
# P: {'1': '81'}
# V: {'1': '81'}
# Irrel: []
#
# True pos 1
# Ha valamit el_p1 kell intézni_v1 valahol, én maga helyett mindent elintézek.\n
# P: {'1': '82'}
# V: {'1': '82'}
# Irrel: []
#
# False neg 1
# False neg 2
# Vajon nem törülné_v1 -e el_p1 azt a magabiztos mozdulatát, mellyel a XX. századi Csák visszamutat_v2 ma a dunántúli város középkori történetére, vissza_p2 a ködszerű múltra.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Szinte bárhol fel_p1 lehet ütni_v1 a Válogatott versek kötetét, s bő ízelítő kínálkozik a tízes évek végéről a sebesen változó, bizarr, elrugaszkodott, nehezen vagy alig érthető képzetekből.\n
# P: {'1': '83'}
# V: {'1': '83'}
# Irrel: []
#
# False neg 1
# Szeretsz?? kérdeztem a lánytól s vártam, hogy mondjon valamit, amitől ketté_p1 hasadnak_v1 a falak.\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# Indulás_v1 haza_p1 !\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# -... ha mégis el_p1 tudja felejteni_v1 ...\n
# P: {'1': '84'}
# V: {'1': '84'}
# Irrel: []
#
# Az ember csavarog.
# P: {}
# V: {}
# Irrel: []
#
# False pos 1
# El_p1 se tudja képzelni_v1 , hogy mást is lehet.\n
# P: {'1': '85'}
# V: {}
# Irrel: ['85']
#
# True pos 1
# - Meg_p1 lehet dögölni_v1 mellette!\n
# P: {'1': '86'}
# V: {'1': '86'}
# Irrel: []
#
# True pos 1
# Az október 26-i ülésükön elhatározva, hogy minden nap össze_p1 fognak ülni_v1 , nem kevesebb, mint 22 pontban rögzítették a tennivalókat.\n
# P: {'1': '87'}
# V: {'1': '87'}
# Irrel: []
#
# True pos 1
# Aki veled le_p1 tudott feküdni_v1 ...\n
# P: {'1': '88'}
# V: {'1': '88'}
# Irrel: []
#
# True pos 1
# Nagy Imre, aki Magad 17 évig voltál emigráns, aki hazatérve ezeket mondottad: " Az volt a bűnöm, hogy szerveztem a földműves nép harcát a feudális nagybirtokrendszer megszüntetéséért, azért, hogy azé legyen a föld, aki megműveli; de ha el_p1 is űztek_v1 innen messze idegenbe, nem voltam földönfutó, lélekben, gondolatban mindig itt voltam köztetek ": ma eljöttek sírodhoz a világ négy sarkából a magyar emigránsoknak ezrei, akik - akárcsak Te - lélekben sohasem szakadtak el a hazától.\n
# P: {'1': '89'}
# V: {'1': '89'}
# Irrel: ['90', '90']
#
# True pos 1
# True pos 2
# És különösképpen utálja azokat, akik ki_p1 merték nyitni_v1 a szájukat, fel_p2 merték emelni_v2 a hangjukat, amikor ő lapult.\n
# P: {'1': '91', '2': '92'}
# V: {'1': '91', '2': '92'}
# Irrel: []
#
# False neg 1
# Kuczka és a vele azonos véleményen lévők határozottan állították, hogy az egyetlen lehetséges, kommunista íróhoz méltó magatartás, amely ezentúl a pártot is segíti, az, hogy nyíltan és tisztán megírják tapasztalataikat, feltárják a hibákat, nem várva_v1 most már meg_p1 , amíg megint ellentmond költészetüknek a valóság, nem is szólva arról, amíg megint fejükre koppint a párt is, hogy a nehéz időkben lehunyt szemmel járták a világot.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Ezt a kiváló tudóst az írás és a publikálás lehetőségeitől tíz éven át fosztotta meg a rendszer, mert bírálni merte - nem sokkal a háború befejezte után, a koalíciós időszak kezdetein - a kommunista párt taktikáját és stratégiáját, felhívta a figyelmet a diktatúra készülő veszélyeire és nem utolsósorban szembe_p1 mert szállni_v1 - Révai Józseffel a kommunista párt és a demokrácia viszonyát illetően.\n
# P: {'1': '94'}
# V: {'1': '94'}
# Irrel: ['93', '93']
#
# True pos 1
# Ha mocskosan törpe a történelem - meg_p1 kell építenünk_v1 a magunk történelmét.\n
# P: {'1': '95'}
# V: {'1': '95'}
# Irrel: []
#
# False neg 1
# Teljes objektivitása ugyanis önmagában van, a maga tisztaságában nem bányászható_v1 ki_p1 .\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Szóval, most mindent oda_p1 tudnál dobni_v1 , vőlegényt, biztonságot, mindent - és én semmit sem ígértem, semmit se kínáltam ezért.\n
# P: {'1': '96'}
# V: {'1': '96'}
# Irrel: []
#
# True pos 1
# De nem tudta megállni, hogy még egyszer el_p1 ne búcsúzzon_v1 Marianntól; most ugyan elég sután, szemlesütve csinálta.\n
# P: {'1': '97'}
# V: {'1': '97'}
# Irrel: []
#
# True pos 1
# A belső udvart a szomszéd üres telek felől is meg_p1 lehet közelíteni_v1 , egy szögesdróttal biztosított vasajtón.\n
# P: {'1': '98'}
# V: {'1': '98'}
# Irrel: []
#
# True pos 1
# Most először érzek olyasmit, hogy egy sejtelem hatására az embernek le_p1 tud esni_v1 hirtelen a hőmérséklete.\n
# P: {'1': '99'}
# V: {'1': '99'}
# Irrel: []
#
# True pos 1
# Inkább majd a végén részletezi az eredményt - bár meg_p1 volt győződve_v1 róla, hogy nem éri meglepetés.\n
# P: {'1': '100'}
# V: {'1': '100'}
# Irrel: []
#
# True pos 1
# - Itt akarsz megfagyasztani bennünket? - vakkant fel valamelyikünk, és be_p1 akart nyitni_v1 egy ajtón, hogy melegebb helyiség után kutasson.\n
# P: {'1': '102'}
# V: {'1': '102'}
# Irrel: ['101', '101']
#
# True pos 1
# Éreztem, hogy meg_p1 kell kapaszkodnom_v1 valamiben.\n
# P: {'1': '103'}
# V: {'1': '103'}
# Irrel: []
#
# True pos 1
# - Semmibe, csak be_p1 kellene táplálni_v1 .\n
# P: {'1': '104'}
# V: {'1': '104'}
# Irrel: []
#
# True pos 1
# - Eleinte még kijárnak a tanyára disznót nevelni, reggel-este etetik őket, de rá_p1 kell jönniük_v1 , hogy egy disznón nem marad több hasznuk ötszáz-ezer forintnál, mert a drága kukoricát már nekik is a boltban kell megvásárolniuk.\n
# P: {'1': '105'}
# V: {'1': '105'}
# Irrel: []
#
# True pos 1
# Tudtam róla, hogy megszállott rendőr, ezért is kapta becézésképpen a nagy francia rendőrzseni nevét, néha éjjel kettőkor hívta fel a kollégáit, hogy mostanáig járt egy körözött betörő nyomában, rábukkant, itt áll a lakása előtt, most le_p1 lehetne tartóztatni_v1 , jöjjenek el segíteni neki.\n
# P: {'1': '107'}
# V: {'1': '107'}
# Irrel: ['106', '106', '108', '108']
#
# False neg 1
# - Ezt a kísérletet néhány megjelölt úszó fadarabbal is épp ilyen jól el_p1 lehetett volna végezni_v1 - mondja F., a sokat tapasztalt öreg környezetvédő szakember.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Mivel tudtam, hogy előbb-utóbb mindenképpen behívnak katonának, meg_p1 akartam előzni_v1 , önként jelentkeztem a Légierőhöz.\n
# P: {'1': '109'}
# V: {'1': '109'}
# Irrel: []
#
# True pos 1
# Arcán elszánt kifejezéssel állt oda a meszelt rajtvonalra, tudtuk, meg_p1 fog tenni_v1 mindent, ami tőle telik.\n
# P: {'1': '111'}
# V: {'1': '111'}
# Irrel: ['110', '110']
#
# True pos 1
# - És te el_p1 akarsz úszni_v1 Verdalóba? - kérdeztem hitetlenül.\n
# P: {'1': '112'}
# V: {'1': '112'}
# Irrel: []
#
# Feltűnően öltözködő, mozgékony kis barátnője mellett úgy tűnt, mint egy nehézkes tengeri hal, vezetője, a fürge pilótahal mellett, és valószínűleg ez is határozta meg kapcsolatuk jellegét.
# P: {}
# V: {}
# Irrel: ['113', '113']
#
# True pos 1
# True pos 2
# El_p1 akart fordulni_v1 , de a lány hirtelen újra ráemelte a szemét, János visszanézett, és a kitágult szemekből megértette, hogy a lány lát rajta valami sebet vagy rendetlenséget, amelyre fel_p2 akarja hívni_v2 a figyelmét.\n
# P: {'1': '114', '2': '115'}
# V: {'1': '114', '2': '115'}
# Irrel: []
#
# True pos 1
# A szakítás mellett szólt az is, hogy Altschuler vagy Nagyezsda is tudomást szerezhet a találkozásokról, és János egyelőre el_p1 akarta kerülni_v1 a botrányt.\n
# P: {'1': '116'}
# V: {'1': '116'}
# Irrel: []
#
# True pos 1
# " A büntetés elején nagyobb fokú nélkülözéssel kell felkelteni a tudatot az elítéltben, hogy a jogsértés súlyos következményekkel jár, és akaratát alá_p1 kell rendelnie_v1 egy felsőbb akaratnak.
# P: {'1': '117'}
# V: {'1': '117'}
# Irrel: []
#
# True pos 1
# "\nEgészen el_p1 is feledtem_v1 a kedves édesapát.\n
# P: {'1': '118'}
# V: {'1': '118'}
# Irrel: []
#
# True pos 1
# Olyan embert, aki érvényt szerez a törvény szavának; s aki azon nyomban le_p1 is köszönt_v1 a tisztéről, mihelyst megszűnt a szükségállapot vagy megoldódott a viszály.\n
# P: {'1': '119'}
# V: {'1': '119'}
# Irrel: []
#
# True pos 1
# Ott az ajtó, a hallba nyílik, ki_p1 kell nyitni_v1 .\n
# P: {'1': '120'}
# V: {'1': '120'}
# Irrel: []
#
# True pos 1
# De hiszen ez meg_p1 van repedve_v1 , folyik a petróleum.\n
# P: {'1': '121'}
# V: {'1': '121'}
# Irrel: []
#
# True pos 1
# Nem akarom, hogy azt higgye, valami tolvaj szomszédságába került - tette_v1 még hozzá_p1 az ujját fölemelve.\n
# P: {'1': '122'}
# V: {'1': '122'}
# Irrel: []
#
# True pos 1
# Tizenkét évig rá_p1 sem néztem_v1 más nőnemű lényre.\n
# P: {'1': '123'}
# V: {'1': '123'}
# Irrel: []
#
# False neg 1
# De ezen a csúcson - s ezt már a regény bizonyítja - elkezdtem gyanakodni erre az épségre, a normára: nem csapott_v1 -e be_p1 , nem zárta -e fölpattinthatatlan tokba azt, ami több, nemesebb volt bennem: " az abnormalitásom ".\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# True pos 2
# - Azért el_p1 ne rídd_v1 magad, szólt az apa, aki nem állhatta meg, hogy el_p2 ne kacagja_v2 magát, oly komikus volt az előrecsuklott térdű, reszkető figura.\n
# P: {'1': '124', '2': '126'}
# V: {'1': '124', '2': '126'}
# Irrel: ['125', '125']
#
# True pos 1
# Ott élek mellette, s nem tudom elhinni - holott nagyon is el_p1 tudta hinni_v1 , meg volt győződve, csak nagy néha nyilallt bele az esztelen gyanú, hogy tán mégsem igaz - mint éjjeli felriadáskor, hogy halottunk nem halt meg.\n
# P: {'1': '127'}
# V: {'1': '127'}
# Irrel: ['128', '128', '129', '129', '130', '130']
#
# True pos 1
# True pos 2
# Nem jutott eszembe, hogy a mennyei dicsőség révült állapotát sajnálatos módon meg_p1 kell előznie_v1 annak, hogy meg_p2 kell halnunk_v2 hozzá.\n
# P: {'1': '131', '2': '132'}
# V: {'1': '131', '2': '132'}
# Irrel: []
#
# True pos 1
# Ebben a sűrű füstben el_p1 se látunk_v1 odáig.\n
# P: {'1': '133'}
# V: {'1': '133'}
# Irrel: []
#
# True pos 1
# Akárhogy is van, hősöm ő nekem, hajtogattam, hogy legalább fikcióvá hazudjam ezt a szörnyűséget, de meg_p1 nem nyugodtam_v1 .\n
# P: {'1': '134'}
# V: {'1': '134'}
# Irrel: []
#
# True pos 1
# Egyszerű vágásokkal, nagyításokkal, egybefényképezésekkel: az Ezeregyéjszaka minden csodáját fel_p1 tudja eleveníteni_v1 a néző szeme előtt: tengeri ütközetet egy lavór vízben, a vízözön, a Mars-utazás, Karthágó pusztulásának képét - makettből.\n
# P: {'1': '135'}
# V: {'1': '135'}
# Irrel: []
#
# False neg 1
# A gyógynövény párlat egyik alkotó elemét ma is csak én tudom, a porcelán régi fénye az ismert hőfokon is csak egy bizonyos összetételű mázzal érhető_v1 el_p1 : ennek a titkát sem fedtem föl.\n
# P: {}
# V: {}
# Irrel: ['136', '136']
#
# - Semmit!
# P: {}
# V: {}
# Irrel: []
#
# True neg
# Szét_p0 vannak azok már a világban, egyik itt, a másik ott, nem törődnek véle.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Ettől sem tanultam meg " főzni ", de megtanultam elkészíteni néhány ételt, főként különböző salátákat, s egy-két komolyabb fogást is, amiből olykor, nagyritkán össze_p1 tud állni_v1 egy-egy vacsora, és amelynek elkészítése ilyenkor, a kudarctól való drukk vagy sokk állandó jelenléte dacára is, inkább kedvemre mint ellenemre van.\n
# P: {'1': '138'}
# V: {'1': '138'}
# Irrel: ['137', '137']
# False neg 2
# True pos 1
# Nehezen tudom elképzelni, hogy apám a valamelyik haszonleső maffiózó által elétárt Porhüvelyt ne vizsgálta_v1 volna meg_p1 alaposan, valóban azt kapja_v2 -e meg_p2 , amit áhít.\n
# P: {'1': '139'}
# V: {'1': '139'}
# Irrel: []
#
# True pos 1
# Ram lelkében mozdult_v1 csak meg_p1 valami, mert ő érteni vélte a Mesternek ideáját.\n
# P: {'1': '140'}
# V: {'1': '140'}
# Irrel: []
#
# True pos 1
# Leszúrlak, ha meg_p1 akarsz lógni_v1 .\n
# P: {'1': '141'}
# V: {'1': '141'}
# Irrel: []
#
# True pos 1
# - Ez egy kétségbeesett segélykiáltás volt, s névvel jegyezve az első eredménye az lett volna, hogy két óra múltán már le_p1 is tartóztattak_v1 volna.\n
# P: {'1': '142'}
# V: {'1': '142'}
# Irrel: []
#
# True pos 1
# Addig is azonban meg kellene komolyan vizsgálni, hogy azok az állami kiadók, amelyeknek elvileg magyar nyelvű könyveket is ki_p1 kellene hozniok_v1 , ezt a feladatukat miért nem teljesítik.\n
# P: {'1': '143'}
# V: {'1': '143'}
# Irrel: []
#
# True pos 1
# Az ilyesmihez pedig hozzá_p1 voltam szokva_v1 .\n
# P: {'1': '144'}
# V: {'1': '144'}
# Irrel: []
#
# True neg
# Vásárlók mind el_p0 .\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Panaszolta is később az igazgató Prielle Kornéliának: " különös asszony ez a Jászai: nekiadtam az Évát, s még csak fel_p1 se csillant_v1 a szeme!
# P: {'1': '145'}
# V: {'1': '145'}
# Irrel: []
#
# False neg 1
# "\nHogy menekűlt az a réműlt kukac, mikor szétbuggyantottad rejtekét! hogy bújt, vissza, az eltűnt éjbe! még beljebb, a mag alá! hogy bújt_v1 csupasz titka be_p1 a takaró húsba, az áldott édenbe, a biztosba!...
# P: {}
# V: {}
# Irrel: []
#
# Szép vonaglása tán hóhéra kezét átkozta, s azt jósolta: " Nem maradsz rejtve te sem a romlástól! nem a leleplezéstől: életed ura a vak véletlen!
# P: {}
# V: {}
# Irrel: []
#
# "...
# P: {}
# V: {}
# Irrel: []
#
# Sorstragédia szinháza lett az a kék szilvaszem...\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Amata megemberelhette magát, gondolta Latinus, általában nem esznek főttet ők este, de reggel nagyon kókadozott, le_p1 kellett vágni_v1 egy bárányt, prédába nem hagy az ember semmit akkor sem, ha világbirodalom ura lesz.\n
# P: {'1': '146'}
# V: {'1': '146'}
# Irrel: []
#
# True pos 1
# True pos 2
# True pos 3
# Az őrrel fertelmesen ordítottak egymásra, míg Annuska ki_p1 nem rohant_v1 , félre_p2 nem tolta_v2 az őrt, és be_p3 nem rántotta_v3 Anzsut meg a képeket a kapun.\n
# P: {'1': '147', '2': '148', '3': '149'}
# V: {'1': '147', '2': '148', '3': '149'}
# Irrel: []
#
# True pos 1
# Elmondtam már, milyenek voltunk, s ebből megérthetitek, hogy Bálint és az őrnagy miért csak nekem mondta meg, hol van Henriett, és miért hitte el nálunk mindenki, amit Bálinték el_p1 akartak hitetni_v1 , hogy Henriett utánament a szüleinek, és velük együtt elhagyta a várost.\n
# P: {'1': '152'}
# V: {'1': '152'}
# Irrel: ['150', '150', '151', '151']
#
# True pos 1
# Megint azt a kétségbeesést érezte, amit már annyiszor át_p1 kellett élnie_v1 , mennyire nem számíthat senkire önmagán kívül, s hogy egy négytagú családban milyen egymagára utaltan él, voltaképpen milyen árván.\n
# P: {'1': '153'}
# V: {'1': '153'}
# Irrel: []
#
# True pos 1
# Hát oda dolgozhatnék a mama, akár a szövetkezetben magában, ott olyan viszonylag maga korabeliek vannak, hetven körüliek, de ha az fárasztaná, ki_p1 is adják_v1 neki a munkát, pepecselhet vele otthon.\n
# P: {'1': '154'}
# V: {'1': '154'}
# Irrel: []
#
# True pos 1
# Késő délután egyszer csak megjelenik József, Jablonczay Lenke alig vet rá pillantást, Szabó Elek annál figyelmesebben nézi, mint aki fel_p1 akarja mérni_v1 , milyen emlékkel kell majd megküzdenie.\n
# P: {'1': '155'}
# V: {'1': '155'}
# Irrel: []
#
# True pos 1
# Komolyan beszélgetni, elmagyarázni, kiben mikor érett meg a felismerés, hogy házasságot kellene kötniök, persze nem volt alkalom, de mire bevégezték az étkezést, valahogy mindketten természetesnek találták már, hogy Amalfi velük maradjon, míg délutáni szolgálata meg_p1 nem kezdődik_v1 .\n
# P: {'1': '157'}
# V: {'1': '157'}
# Irrel: ['156', '156']
#
# True pos 1
# Addig körmöl, míg az újbóli és újbóli konyak adagok rá_p1 nem hozzák_v1 az álmosságot.\n
# P: {'1': '158'}
# V: {'1': '158'}
# Irrel: []
#
# True pos 1
# Már indul_v1 is vissza_p1 .\n
# P: {'1': '159'}
# V: {'1': '159'}
# Irrel: []
#
# True pos 1
# Érdekes, hogy ezzel a levelezéssel együtt olvasva Berzsenyi költeményeit, azok egymást elragadóan gazdagítják és ki_p1 is egészítik_v1 .\n
# P: {'1': '160'}
# V: {'1': '160'}
# Irrel: []
#
# True pos 1
# Nyakát hátraszegte, derekát kifeszítette, mert ott érezte szívében azt az erőt, amely azt súgta neki, hogy nincs a hadnagynak olyan feltétele, amelyet most el_p1 ne fogadna_v1 boldogan.\n
# P: {'1': '161'}
# V: {'1': '161'}
# Irrel: []
#
# True pos 1
# True pos 2
# De más tekintetben is pazarló módon viselte magát, szólván is dagadozva, mintha meg_p1 akarná venni_v1 az egész Hargitát:\nHazámban, a Székelyföldön fel_p2 vannak háborodva_v2 .\n
# P: {'1': '162', '2': '163'}
# V: {'1': '162', '2': '163'}
# Irrel: []
#
# False neg 1
# True pos 1
# S így búslakodván érzetem csapkodásaiban, kedves anyám jutott eszembe, s el_p1 is gondoltam_v1 , hogy bezzeg az ő kies kertjében más gyümölcs termik; s el_p1 azt is, hogy az a gyümölcs most jobb volna nekem, mert anyám nem azt akarná, hogy én álljak helyt a bajban, hanem azt inkább, hogy az öröm állja meg mellettem a helyét.\n
# P: {'1': '164'}
# V: {'1': '164'}
# Irrel: ['165', '165']
#
# True pos 1
# De ahogy oldozta volna a cipőt, Mihályka elhúzta álmában a lábát; majd azután is elhúzta folyton, valahányszor az anyja le_p1 akarta venni_v1 róla a cipőt.\n
# P: {'1': '166'}
# V: {'1': '166'}
# Irrel: []
#
# True pos 2
# Adjál csak ide pénzt: ne félj, mindjárt meg_p2 fogja mondani_v2 a véleményét a kántor úr.\n
# P: {'2': '167'}
# V: {'2': '167'}
# Irrel: []
#
# True pos 1
# ( Ez be_p1 volt karikázva_v1 .)\n
# P: {'1': '168'}
# V: {'1': '168'}
# Irrel: []
#
# True pos 1
# Másolt: " Ma még én menjek át...! sóhajtotta Lipton, és akkor a döntőben ki_p1 is kaphatok_v1 , 42-42 ponttal állunk, A.A.A.A. és én, és nem baj a második hely.\n
# P: {'1': '170'}
# V: {'1': '170'}
# Irrel: ['169', '169']
#
# True pos 1
# True pos 2
# Ha meg_p1 vagy fázva_v1 , nem annyi már, ha rá_p2 is fázol_v2 .\n
# P: {'1': '171', '2': '172'}
# V: {'1': '171', '2': '172'}
# Irrel: []
#
# False neg 1
# De Jucika riadtan kapja_v1 a kezét el_p1 .\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Már ki_p1 is derült_v1 újra a képünk Rózsikával.\n
# P: {'1': '173'}
# V: {'1': '173'}
# Irrel: []
#
# True neg
# - Meg_p0 , drágám!
# P: {}
# V: {}
# Irrel: []
#
# True neg
# True pos 1
# True pos 2
# Meg_p0 !\nmég egyszer sem sírta el magát én hiába zokogok a lyukas zoknikba a lyukakkal teli ólomteknőbe ki_p1 kell várnom_v1 gabit ahogy egyszer csak némán felsír zokog egész nap a rádióban én meg csapkodni kezdem a hasam úgy röhögök igen én is benne a rádióban úgy röhögök a boldogságtól hogy a gabi végre ismét: sír. nem csak tisztábban okosabban tagol kevesebbet affektál s főleg nem patetizál hanem ismét: sír. milyen szép lesz mennyire igazi reggel felcsapom a kossuthot és hallom benne ahogyan gabi: sír. és aztán teszem szépen a dolgomat megyek ide-oda ólálkodok itt-ott néha talán fel_p2 is jegyzek_v2 valamit de közben tudom ha hazaérek s ismét felcsapom a kossuthot hallani fogom benne ahogyan gabi: sír. és hát ez persze többek között: olyan kosztolányis is. a nagysikerű előadás másnapján a következő sorokat olvashattuk a magyar szó-ban:\nÁllva alvók.
# P: {'1': '175', '2': '176'}
# V: {'1': '175', '2': '176'}
# Irrel: ['174', '174']
#
# True pos 1
# Fel_p1 vannak függesztve_v1 , mint a lampionok.\n
# P: {'1': '177'}
# V: {'1': '177'}
# Irrel: []
#
# True pos 1
# True pos 2
# Tulajdonképpen, ők ily önzetlenül ajándékozgatják egymást mindaddig, mígcsak fel_p1 nem cseperednek_v1 és képzeletük el_p2 nem romlik_v2 .\n
# P: {'1': '178', '2': '179'}
# V: {'1': '178', '2': '179'}
# Irrel: []
#
# False neg 1
# [2] Az idegen állampolgárok és a hontalanok csakis valamely nemzetközi megállapodás alapján vagy a kölcsönösség feltételei között adhatók_v1 ki_p1 .\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# True pos 2
# [4] A kormány által elfogadott határozatokat és rendeleteket alá_p1 kell írnia_v1 a miniszterelnöknek és ellenjegyezniük kell az alkalmazásba tételükre kötelezett minisztereknek, és azokat közzé_p2 kell tenni_v2 Románia Hivatalos Közlönyében.\n
# P: {'1': '180', '2': '181'}
# V: {'1': '180', '2': '181'}
# Irrel: []
#
# True pos 1
# True pos 2
# Figyelemmel arra, hogy ilyen esetek a gyakorlatban számos alkalommal és élethelyzetben fordulnak, illetve fordulhatnak elő, az az álláspontunk, hogy a jogalkotónak egyértelműen meg_p1 kell határoznia_v1 a konfliktusok esetén követendő eljárás - " egyeztetés " - szabályait, és ki_p2 kell mondania_v2 azt, hogy az egyetértési, illetőleg véleményezési jog figyelmen kívül hagyásával hozott döntésekhez milyen jogkövetkezmény fűződik.\n
# P: {'1': '183', '2': '184'}
# V: {'1': '183', '2': '184'}
# Irrel: ['182', '182']
#
# False neg 1
# Sokszor mereven értelmezték, adott esetben a gyermek ellen fordították azokban azt a gyermekvédelmi törvényben deklarált elvet is, amely szerint " szociális okból gyermek nem emelhető_v1 ki_p1 a családból ".\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Békéscsabát fel_p1 kell zárkóztatnunk_v1 először Magyarországhoz, hogy 2002-ben ott lehessünk az unió szintjén - még ha az egyik legalsó szinten is.\n
# P: {'1': '185'}
# V: {'1': '185'}
# Irrel: []
#
# True pos 1
# Én azt mondtam el kompromisszumként, hogy jogtechnikailag az pontosan olyan megoldás lesz számomra, hogy valamennyi esetben - erre mondtam azt, hogy más papírt kell írnunk sok száz beszerzésnél - meg_p1 lesz említve_v1 a (3) bekezdésben eredetileg szereplő tárgyköre a bizottsági véleményalkotásnak.\n
# P: {'1': '187'}
# V: {'1': '187'}
# Irrel: ['186', '186']
#
# Úgy tudom, hogy a személyi ügyeket általában zárt ülésen szokták tárgyalni, kivéve akkor, ha az érintett felek beleegyeznek a nyílt ülésbe.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Meg_p1 kell mondanom_v1 , most nem látom, hogy van -e ilyen nyilatkozat.\n
# P: {'1': '188'}
# V: {'1': '188'}
# Irrel: []
#
# True pos 1
# Ezeket az áremeléseket a kórházaknak ki_p1 kellett fizetni_v1 , ugyanakkor a visszapótlás csak 20 százalék értékben történt meg.\n
# P: {'1': '189'}
# V: {'1': '189'}
# Irrel: ['190', '190']
#
# True pos 1
# A kihívásokról nem szeretnék beszélni, a listák a képernyőn is megjelentek, verbálisan a szövegben is olvashatóak voltak, hármat azonban - úgy érzem - külön is meg_p1 kell említenünk_v1 , mert ezek nagyon jelentősen meghatározzák az Általános Rendezési Tervet.\n
# P: {'1': '191'}
# V: {'1': '191'}
# Irrel: []
#
# True pos 1
# Lehetőleg el_p1 kellene kerülni_v1 , hogy olyan jogértelmezési kérdésekbe bonyolódjunk, mint hogy a közgyűlési határozatot a Tulajdonosi Bizottság betartotta -e vagy sem, hisz éppen ezért javasolta a bizottság a 2. határozati javaslatot, hogy most konkrétan próbáljunk meg előrejutni ebben a kérdésben.\n
# P: {'1': '192'}
# V: {'1': '192'}
# Irrel: ['193', '193']
#
# False neg 1
# Azt, hogy mi módon teszi_v1 ezt meg_p1 a koalíció vagy mi módon nem, azzal van, amikor egyetértünk, és van, amikor nem.\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# Kettő: ha arra gondolna, amire elvileg gondolhatna egy teljesen más tényállás esetén, a ki_p1 nem küldött_v1 anyag napirendre vételéről, az most nem áll fenn.\n
# P: {}
# V: {}
# Irrel: ['194', '194']
#
# True pos 1
# Azt is el_p1 kell mondanom_v1 , számomra öröm az, hogy - bár kormánypárt és ellenzék, nyilván fővárosi szinten is, számos alkalommal összecsap - amikor arról van szó, hogy a főváros közbiztonsági helyzetét, a főkapitány úr beszámolóját tárgyaljuk, akkor ebben a kérdésben a felelősségünkre alapozva végül is egy irányba tudunk menetelni.\n
# P: {'1': '195'}
# V: {'1': '195'}
# Irrel: []
#
# True pos 1
# De ha valóban lenne ilyen, ennyire speciálisan ezekre a feladatokra szakosodott iskola, ezek a gyerekek, akik súlyos hátrányokkal küszködnek, nagyon nehezen viselnék el, ha át_p1 kellene menniük_v1 új közösségbe, új iskolába.\n
# P: {'1': '197'}
# V: {'1': '197'}
# Irrel: ['196', '196']
#
# True pos 1
# Az első módosító javaslat Marsi Péter Páltól származik, amely csak írásban került elénk, úgyhogy fel_p1 kell olvasnom_v1 .\n
# P: {'1': '198'}
# V: {'1': '198'}
# Irrel: []
#
# False neg 1
# Egyet nagyon határozottan el_p1 kell, hogy hárítsak_v1 : akkor mi nem tartoztunk a kormányzó pártok közé.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Mivel ezt a módosító-javaslat-csomagot most kaptam meg, természetesen fel_p1 fogom olvasni_v1 , ahogy ez ilyenkor szokott lenni.\n
# P: {'1': '200'}
# V: {'1': '200'}
# Irrel: ['199', '199']
#
# True pos 1
# Tehát ezen a területen a felszíni tömegközlekedés korszerűsítését, az e hhez szükséges felszínrendbetételt, mindent meg_p1 kellene csinálni_v1 .\n
# P: {'1': '201'}
# V: {'1': '201'}
# Irrel: []
#
# True pos 1
# Tehát egy olyan felvetést tett az illető, amit valószínűleg vissza_p1 fog vonni_v1 , mert csacsiság volt, nem tekintette át a jogszabál yokat.\n
# P: {'1': '202'}
# V: {'1': '202'}
# Irrel: ['203', '203']
#
# True pos 1
# Az alkalmasság elbírálásába a jelenlegi használatba vevőt be_p1 kell vonni_v1 .
# P: {'1': '204'}
# V: {'1': '204'}
# Irrel: []
#
# True pos 2
# False pos 1
# "\nEl_p2 tud készülni_v2 , egy ekkora létesítménynek egy hónap alatt el_p1 kell tudni készülni_v1 .\n
# P: {'2': '205', '1': '206'}
# V: {'2': '205'}
# Irrel: ['206']
# False neg 1
# (Marsi Péter Pál: Miért, le_p1 van zárva_v1 a vita?)\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Megvártam, amíg egy kicsit csend lesz, mert a saját szavamat nem értem, ami nem olyan nagy baj, de a kérdésnek mégiscsak el_p1 kell hangozni_v1 .\n
# P: {'1': '207'}
# V: {'1': '207'}
# Irrel: []
#
# False neg 1
# Ha azt mondom, hogy 2-300 milliárd beruházásigényről van szó, és ehhez képest 3 milliárd kerül_v1 ide be_p1 , akkor azt kell mondjam, hogy az aránytalan, ez így hiba.\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# True neg
# True neg
# True pos 1
# Az elnyert támogatás kizárólag a tárgyévben meghirdetett tervpályázatok céljára használható_v1 fel_p1 .\n* Vissza_p0 a tartalomjegyzékhez\nÚ vissza_p0 a címlaphoz\n(1) Minden sírhelytábla számát jelzőoszlopon, a sírhelysorok és sírhelyek számát pedig a sorokon túl jól látható helyen fel_p1 kell tüntetni_v1 .\n
# P: {'1': '208'}
# V: {'1': '208'}
# Irrel: []
#
# False neg 1
# True pos 1
# Az erőmű építés vonatkozásában megvizsgálandó annak lehetősége is, hogy a beruházás több lépcsőben, 3 év alatt hogyan valósítható_v1 meg_p1 :\nA felsorolt megoldásoknak meg_p1 kell felelni_v1 a mindenkor érvényes forgalmi rend kialakítására vonatkozó jogszabálynak.\n
# P: {'1': '209'}
# V: {'1': '209'}
# Irrel: []
#
# True pos 1
# Ha tulajdonos túlszámlázást megállapító kifogása helytálló, a többletösszeget és időarányos kamatait tulajdonos részére vissza_p1 kell fizetni_v1 , vagy kérésére azt az esedékes díjfizetési kötelezettségébe kell betudni.\n
# P: {'1': '210'}
# V: {'1': '210'}
# Irrel: []
#
# False neg 1
# (11) A vonaljegyek vissza_p1 nem válthatók_v1 .\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Ezek mind-mind eltérő szabályokkal bonyolódnak, s ember legyen a talpán, akár felszámoló, akár bíró az illető, aki ezt folyamatában szakszerűen végig_p1 tudja követni_v1 .\n
# P: {'1': '211'}
# V: {'1': '211'}
# Irrel: []
#
# True pos 1
# Vajon indokolt -e, hogy a Szocialista Párt frakcióvezetője magyarázkodik, hogy egy kormányzati szándék komoly és azt tényleg be_p1 akarják tartani_v1 , amit bejelentettek?\n
# P: {'1': '212'}
# V: {'1': '212'}
# Irrel: []
#
# False neg 1
# A történelemben eddig elő_p1 nem fordult_v1 feladatok elé kerültünk, és ennek is viseljük gondokat okozó terhét.\n
# P: {}
# V: {}
# Irrel: []
#
# Mi nem vagyunk egyértelműen az állami beavatkozásnak az ellenzői.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# El_p1 szeretném mondani_v1 , sőt, a Kisgazdapárt igényli az állam óvó és védő beavatkozását a gazdaságba, hiszen ma nekünk azzal kell szembenézni, hogy a Coca-Colával kell versenyezni a Szobi szörp családnak.\n
# P: {'1': '213'}
# V: {'1': '213'}
# Irrel: []
#
# True pos 1
# Tudomásunk van arról, hogy ezt a törvényt az Opel meg_p1 kívánja támadni_v1 az Alkotmánybíróság előtt.\n
# P: {'1': '214'}
# V: {'1': '214'}
# Irrel: []
#
# True pos 1
# Én a sportegészségügy, a sportbiztosításnak a maximális híve vagyok, és aki erre áldozza az életét, vagy aki nem az életét áldozza rá és nem sportból, a sport eredményéből akar megélni, hanem csak egészséges ember akar lenni, annak is meg_p1 kell adni_v1 az esélyt, hogy ellenőrzötten, felügyelet mellett és erről a biztosítás mellett is eredményesen tevékenykedhessen.\n
# P: {'1': '216'}
# V: {'1': '216'}
# Irrel: ['215', '215']
#
# True pos 1
# True pos 2
# True pos 3
# True pos 4
# Mert ha csak arra hegyezzük ki a kérdést, hogy le_p1 kell lőni_v1 , azt meg_p2 lehet csinálni_v2 : el_p3 lehet ejteni_v3 a vadat teljesen titokban, haza_p4 lehet vinni_v4 , lehet hasznosítani.\n
# P: {'1': '218', '2': '219', '3': '220', '4': '221'}
# V: {'1': '218', '2': '219', '3': '220', '4': '221'}
# Irrel: ['217', '217']
#
# True pos 1
# True pos 2
# True pos 3
# Az önkormányzat létrejöttétől eltelt időt azonban ki_p1 kell értékelni_v1 és meg_p2 kell nézni_v2 , hogy az a törvény, amely jelenleg szabályozza az önkormányzatok működését, mennyiben állja ki a gyakorlat próbáját, és meg_p3 kell találni_v3 azokat a pontokat, ahol kisebb-nagyobb változásokkal a rendszer működtethető.\n
# P: {'1': '222', '2': '223', '3': '225'}
# V: {'1': '222', '2': '223', '3': '225'}
# Irrel: ['224', '224']
#
# False neg 1
# Ugyanakkor rá_p1 kell arra mutatnom_v1 , hogy - a háromoldalú tárgyalásokat is beleszámítva, amelyek közismerten 1989-ben történtek - most már nyolc éve folyik az egész jogrendünk átalakítása, és bizony megítélésem szerint ennek a nyolc évnek bőségesen elegendőnek kellett volna lennie ahhoz, hogy egy új büntetőkódex kerüljön megalkotásra.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# True pos 2
# Emberarcúvá kell formálni s meg_p1 kell nemesíteni_v1 az ember tágabb környezetét, és meg_p2 kell teremtenie_v2 az élelmiszereket és egyéb anyagokat, amelyekre az emberiségnek szüksége van.\n
# P: {'1': '226', '2': '227'}
# V: {'1': '226', '2': '227'}
# Irrel: []
#
# False neg 2
# False neg 3
# True pos 1
# Most közlöm önnel, az eddigi 50 százalékos fogyasztásiadó-visszatérítés, ami a gázolajba be_p1 volt építve_v1 , most 70 százalékosra emelkedett fel 1996. január 1-jétől; gépek beszerzéséhez és vásárlásához 25 százalék vissza_p2 nem térítendő_v2 támogatást biztosítunk; beruházásokhoz, építményekhez fix összegű támogatást adunk, ami négyzetméterenként négyezertől nyolcezer forintig terjedhet, és ez - még egyszer mondom - vissza_p3 nem térítendő_v3 támogatás.\n
# P: {'1': '228'}
# V: {'1': '228'}
# Irrel: ['229', '229']
#
# True pos 1
# Az elemzés alapján meg_p1 kell tervezni_v1 a lehetőségek szerinti legnagyobb közelítési költségeket.\n
# P: {'1': '230'}
# V: {'1': '230'}
# Irrel: []
#
# Ez a központi szervezet, amely nem más, amelynek rendeltetése az lenne, hogy a nemzetgazdaság szempontjából jelentős gazdasági visszaélések gyanújának felmerülése esetén nyomozást és operatív eljárást foganatosíthasson.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Meg_p1 kell mondanom_v1 , hogy ez egyáltalán nem ismeretlen dolog a nyugati gyakorlatban, Nagy-Britanniában, illetve Angliában már hatodik éve működik a kormány mellett egy ilyen szervezet.\n
# P: {'1': '231'}
# V: {'1': '231'}
# Irrel: []
#
# True pos 1
# Úgy gondolom, úgy kellene ma innen elmennünk, hogy közösen meg_p1 tudnánk állapodni_v1 néhány dologban.\n
# P: {'1': '232'}
# V: {'1': '232'}
# Irrel: []
#
# False neg 1
# A rendőrség katonai jellegű struktúrája érintetlenül maradt és ugyanez mondható_v1 el_p1 a többi fegyveres szervről is.\n
# P: {}
# V: {}
# Irrel: []
#
# Feloldást egy más szervezeti struktúra hozhat, ahol a tenni akarók megfelelő szerepet, feladatot, hatáskört kapnak - egyenértékű felelősség mellett.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Tovább kell erősíteni a tűzoltóság önkormányzati jellegét, de fenn_p1 kell tartani_v1 az állami felügyelet rendszerét, valamint a nem osztható feladatokat, például az oktatási és műszaki fejlesztés, kutatás tekintetében.\n
# P: {'1': '234'}
# V: {'1': '234'}
# Irrel: ['233', '233']
#
# True pos 1
# Én tehát mindenféleképpen még most is, függetlenül attól, hogy a bizottsági tárgyalások során a módosító indítványoknak ebben a szakaszában van néhány, amely elfogadásra került, mind a hatékonyságot és a gazdaságosságot szolgálja, mint említettem, azonban kicsit úgy érzem, hogyha nincs meg a törvényben az a munkaszervezet, amelyről most szóltam, akkor csonka lesz ez a tevékenység ilyen szempontból, hiszen akkor megvalósul az, hogy oda_p1 kell adni_v1 a polgári titkosszolgálatokat irányító miniszter alárendeltségébe, vagy valahol működtetni kell, vagy pedig légüres tér, amely, azt hiszem, számomra egyértelmű, hogy működőképesség szempontjából bonyolult lesz.\n
# P: {'1': '236'}
# V: {'1': '236'}
# Irrel: ['235', '235']
#
# False neg 1
# Egyetlenegy esetben sem merült_v1 azonban fel_p1 a politikai megfontolás.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# True pos 2
# Éppen ezért tehát az az álláspontja a Fidesz-Magyar Polgári Párt parlamenti frakciójának, hogy a humán privatizációs stratégiára nézve is a kormánynak be_p1 kell nyújtania_v1 egy országgyűlési határozati javaslatot és ezt a kérdést is meg_p2 kell tárgyalnia_v2 a parlamentnek, nehogy áttekinthetetlen és később állandó viták kereszttüzébe kerülő privatizáció történjen.\n
# P: {'1': '237', '2': '238'}
# V: {'1': '237', '2': '238'}
# Irrel: []
#
# False neg 1
# Tudom, hogy a főváros zászlajával foglalkozni - éppen az előbb idézett önkormányzatról szóló törvény előírásai alapján - az Országgyűlés mint olyan nem jogosult, hiszen az csak a főváros képviselő- testülete által állapítható_v1 meg_p1 , rögzíthető és módosítható.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Ez pedig nem megy másként, mint úgy, hogy néha kellemetlen lépéseket is meg_p1 kell tenni_v1 , bármennyire is sajnáljuk azokat az embereket, akik ebben a mai helyzetben elvesztik munkahelyeiket.\n
# P: {'1': '239'}
# V: {'1': '239'}
# Irrel: []
#
# True pos 1
# True pos 2
# Elmúlt egy év, és a statisztikai adatok valóban fel_p1 kell hívják_v1 a figyelmünket arra, hogy a helyzet romlását valami módon meg_p2 kell állítani_v2 .\n
# P: {'1': '240', '2': '241'}
# V: {'1': '240', '2': '241'}
# Irrel: []
#
# True pos 1
# Az átfogó módosító javaslat pontosan meg_p1 fogja határozni_v1 azokat a feltételeket, amelyek megtartásával az intézményfenntartó önkormányzatok dönthetnek.\n
# P: {'1': '242'}
# V: {'1': '242'}
# Irrel: []
#
# False neg 2
# True pos 1
# ...
# P: {'1': '261'}
# V: {'1': '263'}
# Irrel: ['262', '262']
#
# True pos 1
# (2) A fegyver nélküli katonai, illetve a polgári szolgálat teljesítésére vonatkozó engedély iránti kérelmet el_p1 kell utasítani_v1 , ha a körülményekből a lelkiismereti okra való hivatkozás alaptalansága megállapítható.\n
# P: {'1': '264'}
# V: {'1': '264'}
# Irrel: []
#
# True pos 1
# (2) Az ajándéksorsolás megrendezését a sorsolás megkezdése előtt legalább 10 nappal be_p1 kell jelenteni_v1 az SZF-hez.\n
# P: {'1': '265'}
# V: {'1': '265'}
# Irrel: []
#
# True pos 1
# A Miniszteri Kabinet 2001. december 28-án kelt, 1767 számú határozata 2 pontjának értelmében, a 15, illetve ennél több dolgozót foglalkoztató vállalatokat a rokkantbiztosító Tb-alap megyei osztályán jegyzékbe veszik, ezért legkésőbb 2005. február 1-ig be_p1 kell nyújtaniuk_v1 a rokkantak munkába való elhelyezéséről és foglalkoztatásáról szóló jelentést a 10-II I számú (éves) űrlapon.\n
# P: {'1': '266'}
# V: {'1': '266'}
# Irrel: []
#
# True pos 1
# 2. A vizsgajegyzőkönyvek alapján felvételi vizsgát tett hallgatók számát el_p1 kell osztani_v1 a Felvételi Bizottság következő tagjai között: a Felvételi Bizottság elnökei, elnökhelyettese, titkára, az alapító képviselője, valamint az apellációs bizottság elnöke.\n
# P: {'1': '267'}
# V: {'1': '267'}
# Irrel: []
#
# False neg 1
# Ez a magyarságkép egyrészt az " odamondás ", a sanyarú helyzetünk " kimondásának " igényéből eredeztethető, ami ' 89 előtt gyűlt fel, és most élhető_v1 ki_p1 igazán.\n
# P: {}
# V: {}
# Irrel: ['268', '268']
# True pos 1
# Akik (Anglia) elöre tudták, hogy a németek bombázni fogják Coventryt, s hagyták lebombázni a polgári lakosságot, csak hogy ki_p1 ne derüljön_v1 : megfejtették a Luftwaffe kódrendszerét (mert ha kiürítik a várost, egyértelművé válik a megfejtés ténye)?\n
# P: {'1': '269'}
# V: {'1': '269'}
# Irrel: []
#
# True pos 1
# Pl. hogy ki szegte meg szavát: el_p1 ne feledd_v1 tisztázni.\n
# P: {'1': '271'}
# V: {'1': '271'}
# Irrel: ['270', '270']
#
# True pos 1
# Mégpedig azért, mert nyakunkon a tavasz meg a nyár, és - csak el_p1 ne kiabáljam_v1 - mintha lanyhulna a melltartó-terror.\n
# P: {'1': '272'}
# V: {'1': '272'}
# Irrel: []
#
# True pos 1
# A múltkor kedves vizslámat elütötte egy autó, az ölemben " mondott " búcsút a közös sétákért, emlékekért és kölcsönös szeretetért, Akkor sírtam, mert ez volt a valóság és el_p1 kellett fogadni_v1 , hogy nincs tovább!\n
# P: {'1': '273'}
# V: {'1': '273'}
# Irrel: []
#
# True pos 1
# Ős patkány terjeszt kórt miköztünk, a meg_p1 nem gondolt_v1 gondolat, belezabál, amit kifőztünk, s emberből emberbe szalad.\n
# P: {'1': '274'}
# V: {'1': '274'}
# Irrel: []
#
# True pos 1
# Tudom, hogy erre jön a (jól beváltnak nem modható, ám már többször bevetett) " birkák vagytok ", " nem lehet felrázni a társaságot ", stb... szöveg, de nem gondoltál_v1 még bele_p1 , hogy lehet, hogy nem azzal a kb. 100 emberrel van baj aki idejárogat, hanem veled?\n
# P: {'1': '275'}
# V: {'1': '275'}
# Irrel: []
#
# True pos 1
# Az, hogy a maga képére teremtette volna az embert, nagyon ellentmond annak, hogy tökéletes volna - viszont arról tanúskodik, hogy az ember iszonyú egy beképzelt majom, mert nincs aki rászóljon, hogy vegye_v1 már észre_p1 magát a nagy öntömjénezés közepette (meglehet, ebben is hasonlít Istenre:) - ebben tehát következetes ez a felfogás).\nén még nem láttam, de szivesen megnézném.
# P: {'1': '276'}
# V: {'1': '276'}
# Irrel: []
#
# False neg 1
# Meg_p1 van_v1 neked?\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Csak tudjuk_v1 már meg_p1 , mi volt ez az erdélyi megmozdulás!\n
# P: {'1': '277'}
# V: {'1': '277'}
# Irrel: []
#
# True pos 1
# Praktikusan ezt az idöhatárt le_p1 kell csökkenteni_v1 méghozzá drasztikusan.\n
# P: {'1': '278'}
# V: {'1': '278'}
# Irrel: []
#
# True pos 1
# Sajnos, nagy fájdalmamra meg_p1 kell védenem_v1 a FIDESZ-MPP-MDF-KDNP-STB-t.\n
# P: {'1': '279'}
# V: {'1': '279'}
# Irrel: []
#
# True pos 1
# Akkora szájjal hirdették, hogy fel_p1 kell lépni_v1 a feketepiac ellen, meg hogy ők milyen tiszták.\n
# P: {'1': '280'}
# V: {'1': '280'}
# Irrel: []
#
# True pos 1
# Tán az IQ hiány teszi mindezt, minden esetre meg_p1 van győződve_v1 a maga mindenhatóságáról.\n
# P: {'1': '281'}
# V: {'1': '281'}
# Irrel: []
#
# False neg 1
# Nem közhelyezek többet, hiszen ha a humor -bár kissé ironikus és cinizmusba hajló - oldala felöl közelítem meg hozzászólásaidat, akkor kimondottan szórakoztatóak, bár le_p1 sem tagdhatod_v1 , a humor keretei közé tartalmat is viszel.\n
# P: {}
# V: {}
# Irrel: ['282', '282']
#
# True pos 1
# Tehét feltéve, de meg_p1 nem engedve_v1 , hogy neked és MaCSnak igazatok van, az évek így számláltatnak: -2, -1, 1, 2 stb.\n
# P: {'1': '283'}
# V: {'1': '283'}
# Irrel: []
#
# True pos 1
# Persze tudtam, hogy nem jön el, hiszen el_p1 kell köszönnie_v1 a barátaitól, ráadásul egy csomó érdekes, nagyszabású buliba meghívták....\n
# P: {'1': '285'}
# V: {'1': '285'}
# Irrel: ['284', '284']
#
# True pos 1
# Meditálni lehet, hogy ej-ej, de szörnyű állat az ember, de ettől még a háborút akkor is el_p1 kell kerülni_v1 .\n
# P: {'1': '286'}
# V: {'1': '286'}
# Irrel: []
#
# True pos 1
# Annyit meg_p1 lehetett állapítani_v1 , hogy egyik sem volt kivilágítva és nem volt közvilágítás sem...\n
# P: {'1': '287'}
# V: {'1': '287'}
# Irrel: []
#
# True pos 1
# Hidd el, hogy így meg_p1 fognak utálni_v1 , és enyhén szólva nem lesz jó neked ide írni!\n
# P: {'1': '289'}
# V: {'1': '289'}
# Irrel: ['288', '288']
#
# True pos 1
# Nézd_v1 csak meg_p1 a filmet.\n
# P: {'1': '290'}
# V: {'1': '290'}
# Irrel: []
#
# False neg 1
# Satya, ezt meg_p1 kellene ám indokolnod_v1 , méghozzá alaposan.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# A kedvencem az a hely, ahol ki_p1 van írva_v1 : a szaunában a fürdőruha viselése kötelező.\n
# P: {'1': '291'}
# V: {'1': '291'}
# Irrel: []
#
# True pos 1
# Nos, ezt kis odafigyeléssel szerintem sokkal meg_p1 lehetne gyorsítani_v1 .\n
# P: {'1': '292'}
# V: {'1': '292'}
# Irrel: []
#
# False neg 1
# False pos 1
# False pos 1
# Az esetek többségében a válaszban szereplő szám mindig meg_p1 tudtam számolni_v1 két ujjamon ;-) Viszont tapasztaltam azt is, hogy sokan a légitársaságnak rónak fel egy csomó olyan dolgot, amiről abszolúte nem tehetnek (pl. felszálláskor liftezett a gép, hülye pilóta ;-))\nSzerintem is jól döntöttek, de a kevésbé durva helyzetekre nézve nem hiszem hogy fel_p1 lehet ezt példaként hozni_v1 .\nterembura-ragi úgy sorolod ezeket a faszságokat, mintha legalábbis te intézted volna, hogy odaát ilyen jó élet legyen. ne felejcsd el lécci, hogy a készbe menekültél át, az USÁ-ban már minden megvolt előtted. tiszteljük egyébként a fogadott hazád iránti szeretedet, és megértjük az identitászavart is, de vissza_p1 lehet venni_v1 az arcból.\n
# P: {'1': '293'}
# V: {'1': '296'}
# Irrel: ['294', '294', '295', '295']
#
# False neg 1
# Pedig ecceri nem mondott_v1 nekem ellent_p1 .\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Esetleg ki_p1 lehetne próbálni_v1 egér formájú kurzorral is...\n
# P: {'1': '297'}
# V: {'1': '297'}
# Irrel: []
#
# True pos 1
# Köszi! (nem fognak átcseszni? nem bírnám elviselni... vagyis: a műsorkiírásból ki_p1 fog derülni_v1 ?\n
# P: {'1': '298'}
# V: {'1': '298'}
# Irrel: []
#
# False neg 1
# Mi nékünk is meg_p1 volt_v1 a magunk esete a vonat " fonökkel ", mely hosszú üvöltözés (ja kérem kell türelem, hangero), némi pénz, kiváló filctollaink elvesztés árán megoldódott.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Amelyiktek megtapasztalta Istent, a legközelebbi tapasztás alkalmával ugyan vegye_v1 már rá_p1 , hogy ne fagyjon le az Internettó kéthetente.\n
# P: {'1': '299'}
# V: {'1': '299'}
# Irrel: ['300', '300']
#
# True pos 1
# " Le_p1 ne törj_v1 , palló, úgy remegsz!\n
# P: {'1': '301'}
# V: {'1': '301'}
# Irrel: []
#
# True pos 1
# Oh ha meg_p1 is érintene_v1 !\n
# P: {'1': '302'}
# V: {'1': '302'}
# Irrel: []
#
# True pos 1
# És ez a szemlélet, egy gyülekezetben ragadt rám. (ugye meglepő) El_p1 kell mondjam_v1 , hogy a barátaim, akik szintén ebbe a gyülekezetbe járnak, széles látókörűek, sok mindennel foglalkoznak, agyilag teljesen épek, mindannyian egyetemisták vagyunk.\n
# P: {'1': '303'}
# V: {'1': '303'}
# Irrel: []
#
# True pos 1
# Tudja Kedves Sehonnai Bitang Ember, élcesebbnél élcesebb megjegyzései helyett, inkább küldte_v1 volna el_p1 vasárnap nekünk azt a mentőcsapatot, amit kértünk Öntől.\n
# P: {'1': '304'}
# V: {'1': '304'}
# Irrel: []
#
# True pos 1
# True pos 2
# :-( Nem elég, hogy ki_p1 kell hagynom_v1 a gyulai hétvégét, most még az útlevelemet is le_p2 kell adnom_v2 , hogy a vízumot elintézzék, csak az utazás (szept. 19.) előtt pár nappal kapom vissza...\n
# P: {'1': '305', '2': '306'}
# V: {'1': '305', '2': '306'}
# Irrel: ['307', '307']
#
# True pos 1
# 3. Muanyag: modern, élettartama ismeretlen (legjobb tudomásom szerint csak becslések vannak rá), házilag egész jól hozzá_p1 lehet nyúlni_v1 , bár elég rohadt meló.\n
# P: {'1': '308'}
# V: {'1': '308'}
# Irrel: []
#
# True pos 1
# Nyugtasd meg, hogy ez nem azt jelenti, hogy meg_p1 kell kívánnia_v1 saját magát, mert nem erről van szó!\n
# P: {'1': '310'}
# V: {'1': '310'}
# Irrel: ['309', '309']
#
# True pos 1
# True pos 2
# Ez így ment egy órán keresztül, akkor abba_p1 kellett hagyniuk_v1 , mert meg_p2 akarták lincselni_v2 őket...\n
# P: {'1': '311', '2': '312'}
# V: {'1': '311', '2': '312'}
# Irrel: []
#
# True pos 1
# Mondja_v1 már meg_p1 valaki, hogy mi az a dödölle!\n
# P: {'1': '313'}
# V: {'1': '313'}
# Irrel: []
#
# True pos 1
# Az amerikai country westernt valamikor kedveltem, most ki_p1 nem állhatom_v1 .\n
# P: {'1': '314'}
# V: {'1': '314'}
# Irrel: []
#
# True pos 1
# Már fel_p1 is vettem_v1 a nyálálló ruhámat, aztán mentem a TVNET-re, de... azért ez is valami.\n
# P: {'1': '315'}
# V: {'1': '315'}
# Irrel: []
#
# True pos 1
# Vagy ők is megpróbálnak összehozni egy váltópártot a baloldalon, beleértve a civil, alternatív, emberi jogi, kisebbségi, szakszervezetis, szabadelvű ÉS a hagyományos baloldali szférát, vagy nekiállnak magukat úgymond, " tisztítani " még egy jó ideig, kb. addig, amíg le_p1 nem mennek_v1 a sokak által várt 12-15%-os népszerűségi indexig.\n
# P: {'1': '316'}
# V: {'1': '316'}
# Irrel: []
#
# A legutolsó ilyen eset - emlékeim szerint - az volt, amikor az a Landeszmann nevű hibbant fütyülősbarackozott.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# El_p1 is határolódtak_v1 tőle a zsidók gyorsan.\n
# P: {'1': '317'}
# V: {'1': '317'}
# Irrel: []
#
# True pos 1
# Istenem macikám neked tényleg be_p1 kéne jönnöd_v1 egy kicsit.\n
# P: {'1': '318'}
# V: {'1': '318'}
# Irrel: []
#
# Igazad van.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Meg_p1 kell oldani_v1 az átmenő forgalom rendezését.\n
# P: {'1': '319'}
# V: {'1': '319'}
# Irrel: []
#
# Mintha az ő fejükben a látszólagos semlegesség eltolódott volna a pátosz, az elfogódottság felé.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# El_p1 lehet képzelni_v1 , hogy imádhatja egymást a két vázolt típus.\n
# P: {'1': '320'}
# V: {'1': '320'}
# Irrel: []
#
# False neg 1
# Akkor meg_p1 kell őket szólitani_v1 , és nem maszatolni, hogy vannak (úgy általában).\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Ha kérdőre vonnának, azzal a naiv mesével állnék elő, fel_p1 nem tételezem_v1 az országos rendőrközpontról, hogy csempészek üzletel(het)nek benne.\n
# P: {'1': '322'}
# V: {'1': '322'}
# Irrel: ['321', '321']
#
# True pos 1
# Összeakadtam egy válaszmányi tag (reform)szocialista ismerősömmel, aki elmesélte, hogy a párt elnöke, Horn Gyula előadta a választmánynak, hogy meg_p1 kellene próbálni_v1 a kisgazdák helyére bekerülni a kormányba.\n
# P: {'1': '323'}
# V: {'1': '323'}
# Irrel: []
#
# True pos 1
# Mindemellett történt ilyen a Várban, tavaly, Napkelte, be_p1 fogom szerezni_v1 , csakazértis, hogy lásd.\n
# P: {'1': '324'}
# V: {'1': '324'}
# Irrel: []
#
# False neg 1
# Ehelyett a kormány a 90 napot meg_p1 nem haladó_v1 táppénzkiadás teljes egészét a munkaadókra terhelné.\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# Jól ki_p1 kell azt használni_v1 .\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Pontosan meg_p1 tudják mondani_v1 , mire vagyok allergiás - ezt magamtól is tudom.\n
# P: {'1': '325'}
# V: {'1': '325'}
# Irrel: []
#
# Gyönyörű, lenyűgöző és csodállatos volt.
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# True pos 2
# El_p1 is késtem_v1 a munkahelyemről :-)))))))) Nyomozzuk_v2 már ki_p2 , hogy most minek kell jönnie, jó?\n
# P: {'1': '326', '2': '327'}
# V: {'1': '326', '2': '327'}
# Irrel: []
#
# True pos 1
# Sajnos nagyon sok a vacak, mesterségesen savanyított termék, de azért rá_p1 lehet akadni_v1 jóra is.\n
# P: {'1': '328'}
# V: {'1': '328'}
# Irrel: []
#
# True pos 1
# Annyi a megjegyzésem, hogy bár szoros a korelláció a polgárosodás és a középosztály között, azért nem teljesen ua. A középosztályt is szokták rétegezni, az alsó részhez tartoznak azok, akik még fenn_p1 tudják tartani_v1 magukat, gyerekeiknek is kb. biztosítani tudják, hogy hasonló poziciót érjenek el. nyugaton is ide tartozik pl. az ipari szakmunkás réteg.\n
# P: {'1': '329'}
# V: {'1': '329'}
# Irrel: []
#
# True pos 1
# Sajnos én azt olvastam egy F1-es fórumon, hogy Hill annyira elszontyolodott a gyenge előadásán, hogy gyakorlatilag azonnal abba_p1 akarja hagyni_v1 .\n
# P: {'1': '330'}
# V: {'1': '330'}
# Irrel: []
#
# True pos 1
# Ha VB akar lenni, akkor nagyon össze_p1 kell kapnia_v1 magát, mert egy-két vezetői vagy boxbeli baki, és akár Frentzen, Irvine és Coulthard is megelőzheti.\n
# P: {'1': '331'}
# V: {'1': '331'}
# Irrel: []
#
# False neg 1
# Írod: " Tehát ott lehet vita közöttünk, hogy jól csinálják -e, illetve kellő eréllyel lépnek_v1 -e fel_p1 ellenük.\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# Egyébként mindkettőjüket sokkolta a bejelentésem, hogy én igen... és izgatottan várják, hogy vajon tényleg nem gondolom_v1 -e meg_p1 .\n
# P: {}
# V: {}
# Irrel: []
#
# False neg 1
# True pos 1
# True pos 2
# :-( Az egyikük át_p1 akarta festeni_v1 a hajam.\nMert mindez szép (még igaz is lehet), de azért mégiscsak hozzá_p1 járulhatott_v1 a riport elkészültéhez az is, hogy a műsoridőt meg_p2 kell tölteni_v2 , lehetőleg olyasmivel amira a néző felkapja a fejét, és jó ha mutatunk is neki valamit, hogy ne felejtse el a szemét a képernyőn tartani.\n
# P: {'1': '332', '2': '333'}
# V: {'1': '332', '2': '333'}
# Irrel: ['334', '334']
#
# Megadtad a neved?
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Be_p1 ne szarjak_v1 a meghatottságtól!\n
# P: {'1': '335'}
# V: {'1': '335'}
# Irrel: []
#
# True pos 1
# Jelenleg ha valamit akarsz [ez az emberek jelentős része számára hosszab, rövidebb kiadványok, prezentációk elkészítését jelenti] akkor meg_p1 kell vásárolnod_v1 egy monstre szoftvert úgy jó 100 eFt-ért.\n
# P: {'1': '336'}
# V: {'1': '336'}
# Irrel: []
#
# True pos 1
# Ez a Normafán túl van, át_p1 kell menni_v1 a buszvégállomáson, és a behajtani tilos táblától kb. 1-2 perc kocsival.\n
# P: {'1': '337'}
# V: {'1': '337'}
# Irrel: []
#
# True pos 1
# Amikor megtértem Isten adott egy olyan hitet nekem, hogy 100%-ig meg_p1 vagyok győződve_v1 , hogy a Biblia Isten szava, és a Szent Szellem által megelevenített Szentírásnak abszolút tekintélye van.\n
# P: {'1': '338'}
# V: {'1': '338'}
# Irrel: []
# True pos 1
# Egyszer egy zsaru éjfél fele alig akarta elhinni, hogy be_p1 van téve_v1 a kontaktlencsém.
# P: {'1': '339'}
# V: {'1': '339'}
# Irrel: []
#
# True pos 2
# El_p2 kellett olvasnom_v2 egy hirdetőtábla szövegét.\n
# P: {'2': '340'}
# V: {'2': '340'}
# Irrel: []
#
# True pos 1
# Lehet, hogy mégis csak be_p1 kéne ruházni_v1 egy Uziba?!\n
# P: {'1': '341'}
# V: {'1': '341'}
# Irrel: []
#
# True pos 1
# Amikor belekezdett a felgöngyölítősdibe, akkor számolnia kellett a következményeivel, hogy sokan ki_p1 fognak akadni_v1 miatta.\n
# P: {'1': '342'}
# V: {'1': '342'}
# Irrel: []
#
# False neg 1
# Samu a jól nevelt Ír szetter be_p1 kászálódott_v1 az ülésre, s mint aki 1 hete nem evett széles nyelvcsapásokkal lenyalta az aznapi bűnjelet.\n
# P: {}
# V: {}
# Irrel: []
#
# True pos 1
# Szerintem ha így folytatódik, lassan az lesz a " jó " flim pl a tévében, amelyiket nem szakítja meg reklám, s a végén a " sötétig " láthatjuk a kockákat, hiszen a jobb film mellé kevesebb reklámot is el_p1 lehet adni_v1 ugyanannyiért, mint amennyit a sorozat ötpercenkénti reklámjai hoznak.\n
# P: {'1': '344'}
# V: {'1': '344'}
# Irrel: ['343', '343']
#
# True pos 1
# De azt is figyeld meg kérlek, hogy melyik modja, hogy végig_p1 kell vinni_v1 a programot, amire (a polgároktól) felhatalmazást kapott!\n
# P: {'1': '346'}
# V: {'1': '346'}
# Irrel: ['345', '345']
#
# True pos 1
# Mindegyiket haza_p1 kellene telepíteni_v1 , mindjárt kissebb lenne a pofájuk.\n
# P: {'1': '347'}
# V: {'1': '347'}
# Irrel: []
#
# 358
# [273, 9, 7, 69]

# %%
# precision:
precision = true_pos / (true_pos + false_pos)
print("Precision: %.4f"%precision)

# recall:
recall = true_pos / (true_pos + false_neg)
print("Recall: %.4f"%recall)

# F1
print("F1: %.4f"%(2 * precision * recall / (precision + recall)))

# accuracy:
print("Accuracy: %.4f"%((true_pos + true_neg) / preverb_count))
# Out:
# Precision: 0.9681
# Recall: 0.7982
# F1: 0.8750
# Accuracy: 0.7821

# %% [markdown]
# ## Step 7: Evaluate the baseline algorithms

# %%
# !cat preverb_output.tsv | python old_connect_prev.py > baseline_output.tsv

# %%
# Basically same procedure as above, debug lines removed, wrapped in a function,
# abstraction over target field name

PREVERB_COUNT, TRUE_POS, FALSE_POS, TRUE_NEG, FALSE_NEG = 0, 1, 2, 3, 4

def evaluate_target_column(input_file_name, target_col_name):
    preverb_count, true_pos, false_pos, true_neg, false_neg = 0, 0, 0, 0, 0

    with open(input_file_name, encoding='utf-8') as infile:
        header = next(infile)
        Word.features = header.strip().split('\t')

        p_testids = {}
        v_testids = {}
        irrelevant_previds = []

        for n, token in enumerate(infile):
            if token.strip() == '':
                for p_testid, p_target_id in p_testids.items():
                    if (p_target_id in irrelevant_previds or  # \i is connected to a non-annotated verb
                        p_testid not in v_testids or          # \i is not connected to any annotated verbs
                        v_testids[p_testid] != p_target_id):  # \i is not connected to |i, but some other |j
                        false_pos += 1
                    else: 
                        true_pos += 1
                p_testids = {}
                v_testids = {}
                irrelevant_previds = []
                continue

            token = Word(token.strip('\n').split('\t'))
            target_id = getattr(token, target_col_name)
            
            if token.testid == '.':
                if target_id not in ('.', ''):
                    irrelevant_previds.append(target_id)
                continue

            if token.testid == 'p0':
                preverb_count += 1
                if target_id in ('.',''):
                    true_neg += 1    # not connected, OK
                else:
                    false_pos += 1   # preverb annotated as \0 connected to anything
                continue

            if token.testid[0] == 'p':
                preverb_count += 1
                if target_id in ('.',''):
                    false_neg += 1   # preverb annotated as \1 etc. should have been connected
                elif token.testid[1:] in p_testids and p_testids[token.testid[1:]] != target_id:
                    false_pos += 1   # previd does not match preverb with the same annotation
                else:
                    p_testids[token.testid[1:]] = target_id
                continue

            if token.testid[0] == 'v' and target_id not in ('.',''):
                v_testids[token.testid[1:]] = target_id
    
    return (preverb_count, true_pos, false_pos, true_neg, false_neg)

def calculate_metrics(results):
    # precision:
    precision = results[TRUE_POS] / (results[TRUE_POS] + results[FALSE_POS])
    print("Precision: %.4f"%precision)

    # recall:
    recall = results[TRUE_POS] / (results[TRUE_POS] + results[FALSE_NEG])
    print("Recall: %.4f"%recall)

    # F1
    print("F1: %.4f"%(2 * precision * recall / (precision + recall)))

    # accuracy:
    print("Accuracy: %.4f"%((results[TRUE_POS] + results[TRUE_NEG]) / results[PREVERB_COUNT]))

print("Evaluate old connect_prev baseline")

results = evaluate_target_column('baseline_output.tsv', 'prevold')
print(results)
assert results[PREVERB_COUNT] == sum([results[TRUE_POS], 
                                      results[FALSE_POS],
                                      results[TRUE_NEG],
                                      results[FALSE_NEG]]) # debug
calculate_metrics(results)
print()

print("Evaluate connect closest baseline")
results = evaluate_target_column('baseline_output.tsv', 'prevclosest')
print(results)
assert results[PREVERB_COUNT] == sum([results[TRUE_POS], 
                                      results[FALSE_POS],
                                      results[TRUE_NEG],
                                      results[FALSE_NEG]]) # debug
calculate_metrics(results)
print()
# Out:
# Evaluate old connect_prev baseline
# (358, 282, 15, 7, 54)
# Precision: 0.9495
# Recall: 0.8393
# F1: 0.8910
# Accuracy: 0.8073
#
# Evaluate connect closest baseline
# (358, 269, 77, 2, 10)
# Precision: 0.7775
# Recall: 0.9642
# F1: 0.8608
# Accuracy: 0.7570

# %% [markdown]
# ## Step 8: Evaluate Stanza preverb connections

# %%
# !cat difficult_validate.txt | python reformat_for_tok.py | docker run -i mtaril/emtsv emstanza-tok > stanzatok_output.txt
# !cat stanzatok_output.txt | python label_to_column.py | \
    docker run -i mtaril/emtsv emstanza-lem | \
    docker run -i mtaril/emtsv emstanza-parse > stanzaparse_output.txt

# %%
from more_itertools import split_at

with open('stanzaparse_output.txt', encoding='utf-8') as infile:
    with open('stanzaprev.txt', 'w', encoding='utf-8') as outfile:
        header = next(infile)
        Word.features = header.strip().split('\t') + ['stanzaid']
        outfile.write(Word.header() + '\n')
        lines = infile.read().split('\n')
        sentences = list(split_at(lines, lambda x: x == ''))
        for s in sentences:
            words = [Word(token.split('\t') + ['.']) for token in s]
            for w in words:
                if w.deprel == 'compound:preverb':
                    w.stanzaid = w.head
                    words[int(w.head) - 1].stanzaid = w.head
            for w in words:
                outfile.write(str(w) + '\n')
            outfile.write('\n')

# %%
results = evaluate_target_column("stanzaprev.txt", 'stanzaid')
print(results)
assert results[PREVERB_COUNT] == sum([results[TRUE_POS], 
                                      results[FALSE_POS],
                                      results[TRUE_NEG],
                                      results[FALSE_NEG]]) # debug
calculate_metrics(results)
print()
# Out:
# (358, 291, 28, 0, 39)
# Precision: 0.9122
# Recall: 0.8818
# F1: 0.8968
# Accuracy: 0.8128

# %% [markdown]
# ## Step 9: Generalising evaluation workflow

# %%
test_set_name = 'difficult_validate'
test_set_raw = test_set_name + '.txt'
test_set_reformatted = test_set_name + '_reformat.txt'
test_set_emtok_output = test_set_name + '_emtok_output.tsv'
test_set_empos_output = test_set_name + '_empos_output.tsv'
test_set_preverb_output = test_set_name + '_preverb_output.tsv'
test_set_baseline_output = test_set_name + '_baseline_output.tsv'

test_set_stanza_tok_output = test_set_name + '_stanzatok_output.tsv'
test_set_stanza_parse_output = test_set_name + '_stanzaparse_output.tsv'
test_set_stanza_ids = test_set_name + '_stanzaids.tsv'

# %%
# !cat {test_set_raw} | python reformat_for_tok.py > {test_set_reformatted}
# !cat {test_set_reformatted} | docker run -i mtaril/emtsv tok > {test_set_emtok_output}
# !cat {test_set_emtok_output} | python label_to_column.py | docker run -i mtaril/emtsv morph,pos > {test_set_empos_output}
# !cat {test_set_empos_output} | python ../preverb > {test_set_preverb_output}
# !cat {test_set_preverb_output} | python old_connect_prev.py > {test_set_baseline_output}

# %%
# !cat {test_set_reformatted} | docker run -i mtaril/emtsv emstanza-tok > {test_set_stanza_tok_output}
# !cat {test_set_stanza_tok_output} | python label_to_column.py | \
    docker run -i mtaril/emtsv emstanza-lem | \
    docker run -i mtaril/emtsv emstanza-parse > {test_set_stanza_parse_output}
# !cat {test_set_stanza_parse_output} | python add_stanzaid.py > {test_set_stanza_ids}

# %%
print("emPreverb results")
results = evaluate_target_column(test_set_baseline_output, 'previd')
calculate_metrics(results)
print()

# initial results:
# emPreverb results
# Precision: 0.9823
# Recall: 0.8006
# F1: 0.8822
# Accuracy: 0.7933

# previous results:
# emPreverb results
# Precision: 0.9842
# Recall: 0.9043
# F1: 0.9426
# Accuracy: 0.8936
    
print("old connect_prev (max2) results")
results = evaluate_target_column(test_set_baseline_output, 'prevold')
calculate_metrics(results)
print()

print("closest verb baseline results")
results = evaluate_target_column(test_set_baseline_output, 'prevclosest')
calculate_metrics(results)
print()

print("stanza results")
results = evaluate_target_column(test_set_stanza_ids, 'stanzaid')
calculate_metrics(results)
print()
# Out:
# emPreverb results
# Precision: 0.9912
# Recall: 0.9684
# F1: 0.9797
# Accuracy: 0.9608
#
# old connect_prev (max2) results
# Precision: 0.9628
# Recall: 0.8407
# F1: 0.8976
# Accuracy: 0.8179
#
# closest verb baseline results
# Precision: 0.7942
# Recall: 0.9648
# F1: 0.8712
# Accuracy: 0.7731
#
# stanza results
# Precision: 0.9119
# Recall: 0.8815
# F1: 0.8964
# Accuracy: 0.8123

# %% [markdown]
# ## Step 10: Evaluation on general (easy) test dataset

# %%
test_set_name = 'gold500_test'
test_set_raw = test_set_name + '.txt'
test_set_reformatted = test_set_name + '_reformat.txt'
test_set_emtok_output = test_set_name + '_emtok_output.tsv'
test_set_empos_output = test_set_name + '_empos_output.tsv'
test_set_preverb_output = test_set_name + '_preverb_output.tsv'
test_set_baseline_output = test_set_name + '_baseline_output.tsv'

test_set_stanza_tok_output = test_set_name + '_stanzatok_output.tsv'
test_set_stanza_parse_output = test_set_name + '_stanzaparse_output.tsv'
test_set_stanza_ids = test_set_name + '_stanzaids.tsv'

# !cat {test_set_raw} | python reformat_for_tok.py > {test_set_reformatted}
# !cat {test_set_reformatted} | docker run -i mtaril/emtsv tok > {test_set_emtok_output}
# !cat {test_set_emtok_output} | python label_to_column.py | docker run -i mtaril/emtsv morph,pos > {test_set_empos_output}
# !cat {test_set_empos_output} | python ../preverb > {test_set_preverb_output}
# !cat {test_set_preverb_output} | python old_connect_prev.py > {test_set_baseline_output}

# !cat {test_set_reformatted} | docker run -i mtaril/emtsv emstanza-tok > {test_set_stanza_tok_output}
# !cat {test_set_stanza_tok_output} | python label_to_column.py | \
    docker run -i mtaril/emtsv emstanza-lem | \
    docker run -i mtaril/emtsv emstanza-parse > {test_set_stanza_parse_output}
# !cat {test_set_stanza_parse_output} | python add_stanzaid.py > {test_set_stanza_ids}

# %%
print("emPreverb results")
results = evaluate_target_column(test_set_baseline_output, 'previd')
calculate_metrics(results)
print()

print("old connect_prev (max2) results")
results = evaluate_target_column(test_set_baseline_output, 'prevold')
calculate_metrics(results)
print()

print("closest verb baseline results")
results = evaluate_target_column(test_set_baseline_output, 'prevclosest')
calculate_metrics(results)
print()

print("stanza results")
results = evaluate_target_column(test_set_stanza_ids, 'stanzaid')
calculate_metrics(results)
print()
# Out:
# emPreverb results
# Precision: 0.9980
# Recall: 0.9780
# F1: 0.9879
# Accuracy: 0.9760
#
# old connect_prev (max2) results
# Precision: 0.9794
# Recall: 0.9694
# F1: 0.9744
# Accuracy: 0.9500
#
# closest verb baseline results
# Precision: 0.9656
# Recall: 0.9876
# F1: 0.9765
# Accuracy: 0.9540
#
# stanza results
# Precision: 0.9604
# Recall: 0.9066
# F1: 0.9328
# Accuracy: 0.8740

# %% [markdown]
# ## Step 11: Evaluation on difficult test dataset

# %%
test_set_name = 'difficult_test'
test_set_raw = test_set_name + '.txt'
test_set_reformatted = test_set_name + '_reformat.txt'
test_set_emtok_output = test_set_name + '_emtok_output.tsv'
test_set_empos_output = test_set_name + '_empos_output.tsv'
test_set_preverb_output = test_set_name + '_preverb_output.tsv'
test_set_baseline_output = test_set_name + '_baseline_output.tsv'

test_set_stanza_tok_output = test_set_name + '_stanzatok_output.tsv'
test_set_stanza_parse_output = test_set_name + '_stanzaparse_output.tsv'
test_set_stanza_ids = test_set_name + '_stanzaids.tsv'

# !cat {test_set_raw} | python reformat_for_tok.py > {test_set_reformatted}
# !cat {test_set_reformatted} | docker run -i mtaril/emtsv tok > {test_set_emtok_output}
# !cat {test_set_emtok_output} | python label_to_column.py | docker run -i mtaril/emtsv morph,pos > {test_set_empos_output}
# !cat {test_set_empos_output} | python ../preverb > {test_set_preverb_output}
# !cat {test_set_preverb_output} | python old_connect_prev.py > {test_set_baseline_output}

# !cat {test_set_reformatted} | docker run -i mtaril/emtsv emstanza-tok > {test_set_stanza_tok_output}
# !cat {test_set_stanza_tok_output} | python label_to_column.py | \
    docker run -i mtaril/emtsv emstanza-lem | \
    docker run -i mtaril/emtsv emstanza-parse > {test_set_stanza_parse_output}
# !cat {test_set_stanza_parse_output} | python add_stanzaid.py > {test_set_stanza_ids}

# %%
print("emPreverb results")
results = evaluate_target_column(test_set_baseline_output, 'previd')
calculate_metrics(results)
print()

print("old connect_prev (max2) results")
results = evaluate_target_column(test_set_baseline_output, 'prevold')
calculate_metrics(results)
print()

print("closest verb baseline results")
results = evaluate_target_column(test_set_baseline_output, 'prevclosest')
calculate_metrics(results)
print()

print("stanza results")
results = evaluate_target_column(test_set_stanza_ids, 'stanzaid')
calculate_metrics(results)
print()
# Out:
# emPreverb results
# Precision: 0.9912
# Recall: 0.9210
# F1: 0.9548
# Accuracy: 0.9149
#
# old connect_prev (max2) results
# Precision: 0.9228
# Recall: 0.7948
# F1: 0.8540
# Accuracy: 0.7500
#
# closest verb baseline results
# Precision: 0.7662
# Recall: 0.9379
# F1: 0.8434
# Accuracy: 0.7314
#
# stanza results
# Precision: 0.9083
# Recall: 0.8924
# F1: 0.9003
# Accuracy: 0.8191
